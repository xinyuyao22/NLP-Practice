# %% [markdown]
# # Homework 2

# %% [markdown]
# In this homework you will be performing some analysis with entity extraction. In particular, you will be looking at the Reuters corpus and trying to construct entity profiles of persons, organizations, and locations. This will require you to iterate through the documents in the Reuters corpus, parse them appropriately, extract entities, and then store the entities along with some surrounding text. Additionally, you will be looking for mechanisms to identify potential relationships between persons and locations.
#
# Throughout this you will need to use NLTK to access the corpus. At the same time, you will need to use an entity extraction system. You can choose to use either NLTK or Spacy. I would strongly suggest using Spacy for the entity extraction portion of this assignment.
#
# The basic idea is to build a knowledge base around the entities you will extract in the Reuters corpus. Normally, this would be a first step to trying to model such things as entity resolution across documents. You could also use this as a first step to analyzing the sentiment towards particular entities. For example, people expressing dissatistfaction at a restaurant or brand.
#
# Follow the below steps and read the comments carefully on the types of tasks your code will need to do.
#
# I would expect that some of you might be able to reuse parts of this code for your project...

# %% [markdown]
# ## Step 1) Import necessary libraries

# %%
# This will be the corpus we work from
from nltk.corpus import reuters

# %%
# I will assume you are using Spacy as a default entity recognizer.
import spacy
# note, the model load can be odd. In some instances your model might have the full name or the short name here.
# if you run into issues here, check the spacy model page at https://spacy.io/usage/models
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Step 2) FIll in the following function to extract the entity, document id, and relevant sentence text from the input

# %%
def extract_entities(doc_id, doc_text):
    analyzed_doc = nlp(doc_text)
    
    # these two dictionaries will include all the persons and locations you find in a document.
    # You will need to add each person or location you encounter in the document to them
    # for the key you can use the text of the entity, for the value you will want to use the document_id and the
    # text of the sentence one challenge could be that an entity might occur multiple times in the document, 
    # thus the value should really be a document id and a list of the text of the sentences ( or something such as that)
    doc_persons = {}
    doc_organizations = {}
    doc_locations = {}
    
    for entity in analyzed_doc.ents:
        if entity.text.strip() != "":
            # one way to represent the document id and the sentence text would be with a tuple
            # thus, you could do:
            relevant_sentence = (doc_id, entity.sent.text)
            
            # add the relevant document id and sentence to the entity record
            if entity.label_ == 'PERSON':
                if entity.text not in doc_persons:
                    doc_persons[entity.text] = []
                doc_persons[entity.text].append(relevant_sentence)
            elif entity.label_ == 'ORG':
                if entity.text not in doc_organizations:
                    doc_organizations[entity.text] = []
                doc_organizations[entity.text].append(relevant_sentence)
            elif entity.label_ == 'LOC':
                if entity.text not in doc_locations:
                    doc_locations[entity.text] = []
                doc_locations[entity.text].append(relevant_sentence)
            
            # Extra credit: resolve different forms of the same name for each person and location inside the same document.
            list_per = list(doc_persons.keys())
            for per1 in list_per:
                for per2 in list_per:
                    if (per1 != per2) & (per1 in per2):
                        try:
                            doc_persons[per2] = doc_persons[per2] + doc_persons[per1]
                            del doc_persons[per1]
                            list_per.remove(per1)
                        except:
                            pass
            
            list_loc = list(doc_locations.keys())
            for loc1 in list_loc:
                for loc2 in list_loc:
                    if (loc1 != loc2) & (loc1 in loc2):
                        try:
                            doc_locations[loc2] = doc_locations[loc2] + doc_locations[loc1]
                            del doc_locations[loc1]
                            list_loc.remove(loc1)
                        except:
                            pass
   
    return doc_persons, doc_organizations, doc_locations

# %% [markdown]
# ## Step 3) Adjust the following code to run the document entity extraction function
# Also, add the entity records you are constructing to your master list of entities
# Note: for the full subission run across all the Reuters documents

# %%
num_docs = len(reuters.fileids())
#  this has a large number of files... 
# you might wish to limit the number of documents you use while developing your technique 
# ex. reuters.fileids()[0:25]

# these two dictionaries will incorporate all the referneces to 
combined_persons = {}
combined_organizations = {}
combined_locations = {}

# this will only iterate over the first 25 documents, for the real submission you will need to run across all documents
for doc_id in reuters.fileids(): 
    # this doc_text variable will give you a text version of the news article. This could be tokenized.
    persons, organizations, locations = extract_entities(doc_id, reuters.open(doc_id).read())
    
    # you will need to write something here to put the persons and locations found in a document into the 
    # combined_persons, combined_organizations, and combined_locations dictionaries.
    # here you will need to consider how to extend the values already in the dictionaries
    # maybe something like:
    for person in persons.keys():
        if person not in combined_persons.keys():
            # add a person key to the combined persons list
            combined_persons[person] = []
            # now here you can add the person's document ids and sentence texts to the dictionary value
        combined_persons[person].append(persons[person])
    for org in organizations.keys():
        if org not in combined_organizations.keys():
            combined_organizations[org] = []
        combined_organizations[org].append(organizations[org])
    for loc in locations.keys():
        if loc not in combined_locations.keys():
            combined_locations[loc] = []
        combined_locations[loc].append(locations[loc])

# %% [markdown]
# ## Step 4) Fill in the following method to look through the content of an entity dictionary to determine the most popular based on number of mentions

# %%
# now that we have the text associated with the entities, 
# you will want to focus on the 500 top entities in each category
# Identify the top 500 entities by the count of their occurrences
def find_most_popular_entities(entity_dictionary):
    # sort through the entities in the dictionary by the number of sentences
    sorted_dic_keys = [k for k, v in sorted(entity_dictionary.items(), reverse=True, key=lambda item: len(item[1]))]
    list_of_dictionary_keys_with_most_mentions = sorted_dic_keys[:500]
    return list_of_dictionary_keys_with_most_mentions

# %% [markdown]
# ## Step 5) Now invoke your top entity mention finder

# %%
# simply get the top persons and locations
top_persons = find_most_popular_entities(combined_persons)
top_locations = find_most_popular_entities(combined_locations)
top_organizations = find_most_popular_entities(combined_organizations)

# %% [markdown]
# ## Step 6) Analyze the most popular entities to determine what words they most frequently occur with

# %%
# use these dictionaries to store the most frequent terms associated with the entities
person_most_popular_terms = {}
organization_most_popular_terms = {}
location_most_popular_terms = {}

# finally, now find the most frequent tokens associated with the entities
for person in top_persons:
    # fill this dictionary with all the words in the context of the person entity
    person_token_dictionary = {}
    sents = []
    for lst in combined_persons[person]:
        for tup in lst:
            sents.append(tup[1])
    for i in range(len(sents)):
        tokens = nlp(sents[i])
        for token in tokens:
            if (token.text not in person) & (token.is_alpha) & (not token.is_stop):
                if token.lemma_ not in person_token_dictionary:
                    person_token_dictionary[token.lemma_] = 1
                else:
                    person_token_dictionary[token.lemma_] += 1
        sorted_token = [k for k, v in sorted(person_token_dictionary.items(), reverse=True, key=lambda item: item[1])]
        person_most_popular_terms[person] = sorted_token[:5]

# finally, now find the most frequent tokens associated with the entities
for organization in top_organizations:
    # fill this dictionary with all the words in the context of the person entity
    organization_token_dictionary = {}
    sents = []
    for lst in combined_organizations[organization]:
        for tup in lst:
            sents.append(tup[1])
    for i in range(len(sents)):
        tokens = nlp(sents[i])
        for token in tokens:
            if (token.text not in organization) & (token.is_alpha) & (not token.is_stop):
                if token.lemma_ not in organization_token_dictionary:
                    organization_token_dictionary[token.lemma_] = 1
                else:
                    organization_token_dictionary[token.lemma_] += 1
        sorted_token = [k for k, v in sorted(organization_token_dictionary.items(), reverse=True, key=lambda item: item[1])]
        organization_most_popular_terms[organization] = sorted_token[:5]

for location in top_locations:
    # fill this dictionary with all the words in the context of the location entity
    location_token_dictionary = {}
    sents = []
    for lst in combined_locations[location]:
        for tup in lst:
            sents.append(tup[1])
    for i in range(len(sents)):
        tokens = nlp(sents[i])
        for token in tokens:
            if (token.text not in location) & (token.is_alpha) & (not token.is_stop):
                if token.lemma_ not in location_token_dictionary:
                    location_token_dictionary[token.lemma_] = 1
                else:
                    location_token_dictionary[token.lemma_] += 1
        sorted_token = [k for k, v in sorted(location_token_dictionary.items(), reverse=True, key=lambda item: item[1])]
        location_most_popular_terms[location] = sorted_token[:5]

# %% [markdown]
# ## Step 7) Present your results of the most popular entities and their associated terms

# %%
# present you results
person_most_popular_terms
# Out:
# {'Avg': ['vs', 'shrs', 'mln', 'note', 'mth'],
#  'Reagan': ['say', 'President', 'trade', 'administration', 'Japan'],
#  'James Baker': ['say', 'Treasury', 'Secretary', 'rate', 'dollar'],
#  'Clayton Yeutter': ['say', 'trade', 'Trade', 'Representative', 'Japan'],
#  'Kiichi Miyazawa': ['Finance', 'Minister', 'say', 'japanese', 'dollar'],
#  'Ecus': ['tonne', 'rebate', 'export', 'maximum', 'kilo'],
#  'Yasuhiro Nakasone': ['Prime', 'Minister', 'say', 'Japan', 'Washington'],
#  'Rotterdam': ['say', 'port', 'union', 'general', 'cargo'],
#  '1986/87': ['tonne', 'mln', 'say', 'crop', 'wheat'],
#  'Satoshi Sumita': ['say', 'Japan', 'Bank', 'rate', 'governor'],
#  'Richard Lyng': ['Agriculture', 'say', 'Secretary', 'Japan', 'farm'],
#  'Louvre': ['say', 'accord', 'agreement', 'Baker', 'currency'],
#  'Nigel Lawson': ['say', 'Chancellor', 'rate', 'Exchequer', 'market'],
#  'Brown': ['Wagner', 'AFG', 'Inc', 'Industries', 'offer'],
#  'Banks': ['billion', 'mark', 'reserve', 'Bundesbank', 'bid'],
#  'Edouard Balladur': ['Minister', 'Finance', 'say', 'french', 'pct'],
#  'Clayton': ['Yeutter', 'say', 'Trade', 'Representative', 'trade'],
#  'Caspar Weinberger': ['Secretary', 'Defense', 'say', 'ship', 'iranian'],
#  'Paul Volcker': ['say', 'Federal', 'Reserve', 'chairman', 'Chairman'],
#  'Karl Otto Poehl': ['Bundesbank', 'say', 'rate', 'Stoltenberg', 'President'],
#  'Gerhard Stoltenberg': ['Finance', 'say', 'Minister', 'german', 'west'],
#  'REAGAN': ['say', 'rate', 'LESSEN', 'oil', 'room'],
#  'Yeutter': ['say', 'trade', 'Clayton', 'Trade', 'Representative'],
#  'Shr': ['vs', 'loss', 'profit', 'dlrs', 'nil'],
#  '1987/88': ['say', 'tonne', 'billion', 'expect', 'year'],
#  'mln': ['vs', 'stg', 'profit', 'net', 'pretax'],
#  'Reuter': ['correspondent', 'say', 'asian', 'official', 'report'],
#  'Margaret Thatcher': ['Prime', 'Minister', 'say', 'british', 'japanese'],
#  'Malcolm Baldrige': ['Secretary', 'Commerce', 'say', 'sale', 'official'],
#  'George Shultz': ['Secretary', 'State', 'say', 'Moscow', 'wheat'],
#  'Donald Trump': ['share', 'say', 'dlrs', 'estate', 'stock'],
#  'Marlin Fitzwater': ['say', 'spokesman', 'White', 'House', 'trade'],
#  'Purolator': ['Hutton', 'share', 'offer', 'say', 'Emery'],
#  'Jorio Dauster': ['say', 'quota', 'president', 'coffee', 'producer'],
#  'Lawson': ['say', 'rate', 'level', 'interest', 'exchange'],
#  'BAKER': ['say', 'rate', 'TREASURY', 'SEES', 'SECRETARY'],
#  'Wagner': ['Brown', 'AFG', 'say', 'Inc', 'Industries'],
#  'Backlog': ['mln', 'vs', 'dlrs', 'shrs', 'billion'],
#  'Paul\n  Volcker': ['say', 'Chairman', 'Federal', 'Reserve', 'Board'],
#  'Baker': ['Hughes', 'say', 'merger', 'decree', 'Department'],
#  'Subroto': ['say', 'oil', 'indonesian', 'Energy', 'Minister'],
#  'Nigel\n  ': ['Chancellor', 'Exchequer', 'Lawson', 'say', 'rate'],
#  'Corazon Aquino': ['President', 'say', 'share', 'arbitration', 'panel'],
#  'Qtr': ['end', 'include', 'mln', 'dlrs', 'Dec'],
#  'Dan Glickman': ['subcommittee', 'say', 'Kan', 'dlrs', 'feedgrain'],
#  'Fernando Santos Alvite': ['Ecuador', 'say', 'OPEC', 'barrel', 'oil'],
#  'Petrobras': ['say', 'oil', 'Saudis', 'company', 'accept'],
#  'Stoltenberg': ['say', 'currency', 'West', 'Paris', 'agreement'],
#  'Hisham Nazer': ['say', 'OPEC', 'oil', 'price', 'mln'],
#  'Jim Wright': ['House', 'Speaker', 'import', 'plan', 'oil'],
#  'Richard\n  Lyng': ['say', 'offer', 'Agriculture', 'Secretary', 'grain'],
#  'Daniel Amstutz': ['say', 'USDA', 'undersecretary', 'soybean', 'agriculture'],
#  'Asher Edelman': ['Inc', 'group', 'investor', 'say', 'Burlington'],
#  'Hajime Tamura': ['Industry', 'Minister', 'Japan', 'trade', 'Trade'],
#  'Inc': ['say', 'Calny', 'acquire', 'dlrs', 'share'],
#  'Carl Icahn': ['TWA', 'say', 'USAir', 'law', 'SEC'],
#  'Richard Gephardt': ['trade', 'surplus', 'country', 'Missouri', 'amendment'],
#  'Manaspas Xuto': ['say', 'conference', 'new', 'week', 'chairman'],
#  'Kenneth Kaunda': ['President', 'auction', 'exchange', 'maize', 'price'],
#  'Michael Wilson': ['Finance', 'Minister', 'say', 'tax', 'canadian'],
#  'REUTER^M\n  \n\n': [],
#  'Eishiro Saito': ['Keidanren', 'say', 'chairman', 'Federation', 'Economic'],
#  'Keidanren': ['Eishiro', 'Saito', 'say', 'Federation', 'Economic'],
#  'Martin T. Sosnoff': ['say', 'Caesars', 'share', 'offer', 'World'],
#  'Robert Brusca': ['say', 'Nikko', 'Securities', 'International', 'market'],
#  'Ronald Reagan': ['say', 'President', 'trade', 'talk', 'Chirac'],
#  'Lyng': ['Secretary', 'Richard', 'Agriculture', 'say', 'offer'],
#  'Arturo Hernandez Grisanti': ['say', 'Energy', 'Minister', 'Mines', 'oil'],
#  'Allegheny': ['say', 'share', 'stock', 'Wilkinson', 'intend'],
#  'Ferdinand Marcos': ['share', 'associate', 'President', 'UCPB', 'government'],
#  'Gerhard\n  ': ['west', 'german', 'Finance', 'Minister', 'profit'],
#  'Cominco': ['pct', 'Lornex', 'share', 'production', 'say'],
#  'Jorge Cardenas': ['coffee', 'manager', 'federation', 'Colombia', 'say'],
#  'Dome': ['say', 'debt', 'dlrs', 'plan', 'TransCanada'],
#  'Revenues': ['dlrs', 'billion', 'mln', 'year', 'increase'],
#  'NOTE:1985': ['include', 'dlrs', 'loss', 'net', 'mln'],
#  'Lloyd Bentsen': ['Senate', 'Finance', 'Committee', 'say', 'tell'],
#  'BALDRIGE': ['say', 'trade', 'deficit', 'SEES', 'ahead'],
#  'Malcolm': ['Secretary', 'Commerce', 'Baldrige', 'Trade', 'Representative'],
#  'Javier Espinosa': ['Ecuador', 'oil', 'say', 'export', 'Venezuela'],
#  'Jovanovich Inc': ['Harcourt', 'Brace', 'say', 'share', 'mln'],
#  'Helmut Kohl': ['Chancellor', 'EC', 'say', 'Jacques', 'german'],
#  'Sanford Margoshes': ['say', 'oil', 'Shearson', 'Lehman', 'Brothers'],
#  'Denis Bra': ['Kanon', 'say', 'council', 'chairman', 'ICCO'],
#  'Jacques Chirac': ['Minister', 'Prime', 'say', 'union', 'government'],
#  'Suharto': ['President', 'oil', 'say', 'company', 'indonesian'],
#  'Richard\n  ': ['Lyng', 'Agriculture', 'Secretary', 'say', 'wheat'],
#  'Willy De Clercq': ['EC', 'Trade', 'concern', 'External', 'Commissioner'],
#  'Jacques Delors': ['Commission', 'EC', 'President', 'say', 'market'],
#  'Manuel Johnson': ['say', 'Federal', 'Reserve', 'Board', 'Vice'],
#  'Jordan': ['say', 'dlrs', 'wheat', 'mln', 'tonne'],
#  'SUPPLY': ['money', 'rise', 'dlrs', 'WEEK', 'FED'],
#  'Gencorp': ['say', 'offer', 'share', 'partnership', 'April'],
#  'Harris': ['say', 'share', 'common', 'filing', 'Securities'],
#  'Melvin Sims': ['say', 'USDA', 'sale', 'tonne', 'export'],
#  'Dan Rostenkowski': ['trade', 'say', 'bill', 'House', 'legislation'],
#  'Mark IV': ['Baird', 'say', 'pct', 'offer', 'stock'],
#  'John Herrington': ['say', 'oil', 'import', 'Energy', 'Secretary'],
#  'vs yr-ago': ['dlrs', 'mln', 'loss', 'shr', 'gain'],
#  'Mij': ['tonne', 'grain', 'Graan', 'Elevator', 'week'],
#  'Gilberto Arango': ['say', 'export', 'president', 'association', 'coffee'],
#  'Helmut Schlesinger': ['Bundesbank',
#   'president',
#   'german',
#   'vice',
#   'central'],
#  'Domes Use': ['NIL', 'Exports', 'Imports'],
#  'Wilf Gobert': ['say', 'Dome', 'Co', 'Peters', 'debt'],
#  'Drew': ['say', 'house', 'year', 'rate', 'rise'],
#  'James Goldsmith': ['Sir', 'takeover', 'company', 'attempt', 'share'],
#  'Baldrige': ['say', 'trade', 'meet', 'Japan', 'United'],
#  'Brian Mulroney': ['say', 'government', 'Prime', 'Minister', 'trade'],
#  'Sullivan': ['mln', 'Kimberley', 'produce', 'long', 'ton'],
#  'Bass': ['say', 'family', 'group', 'share', 'Horizon'],
#  'Carl Lindner': ['Taft', 'say', 'control', 'company', 'American'],
#  'Jose Sarney': ['President', 'foreign', 'brazilian', 'announce', 'dollar'],
#  'Rilwanu Lukman': ['OPEC', 'say', 'price', 'oil', 'output'],
#  'Mario Gabelli': ['say', 'share', 'Securities', 'Exchange', 'Commission'],
#  'Citgo': ['West', 'Texas', 'posting', 'Intermediate', 'increase'],
#  'A. William Reynolds': ['chairman', 'GenCorp', 'company', 'General', 'say'],
#  'Dart': ['say', 'SGL', 'offer', 'Supermarkets', 'General'],
#  'Martin Sosnoff': ['say', 'Caesars', 'share', 'World', 'offer'],
#  'Patrick Leahy': ['D', 'Chairman', 'vt', 'Agriculture', 'Committee'],
#  'Mikhail Gorbachev': ['leader', 'Kremlin', 'soviet', 'describe', 'sector'],
#  'Malcolm Baldrige\n  ': ['say', 'trade', 'Secretary', 'market', 'Commerce'],
#  'Kobena Erbynn': ['delegate', 'group', 'ICCO', 'say', 'buffer'],
#  'Dudley Taft': ['vice', 'chairman', 'say', 'share', 'company'],
#  'King Fahd': ['OPEC', 'oil', 'price', 'Saudi', 'Arabia'],
#  'Almir Pazzionotto': ['Labour', 'Minister', 'say', 'government', 'force'],
#  'Michael Smith': ['Trade', 'GATT', 'Deputy', 'Representative', 'minister'],
#  'Ramon Diaz': ['say', 'share', 'PCGG', 'buy', 'tell'],
#  'Cordoba': ['Santa', 'Fe', 'La', 'Pampa', 'Buenos'],
#  'Kiichi\n  Miyazawa': ['say', 'Paris', 'japanese', 'strengthening', 'yen'],
#  'Andreas Papandreou': ['Turkey', 'Prime', 'Minister', 'greek', 'turkish'],
#  'Gholamreza Aqazadeh': ['Minister', 'iranian', 'Oil', 'agency', 'say'],
#  'Heublein Inc': ['mln', 'dlrs', 'say', 'Metropolitan', 'PLC'],
#  'Brent': ['dlrs', 'value', 'crude', 'ct', 'Bonny'],
#  'Barber Conable': ['World', 'Bank', 'President', 'say', 'economy'],
#  'Beryl Sprinkel': ['say', 'tax', 'increase', 'dollar', 'Japan'],
#  'Southmark': ['say', 'right', 'Sosnoff', 'offer', 'April'],
#  'Cotton': ['planting', 'progress', 'Lower', 'Valley', 'mln'],
#  'Rice': ['say', 'grain', 'price', 'billion', 'wheat'],
#  'Irwin Jacobs': ['say', 'company', 'pct', 'stock', 'Gillette'],
#  'Henry Gluck': ['say', 'Sosnoff', 'offer', 'Caesars', 'chairman'],
#  'Scott': ['mln', 'dlrs', 'say', 'Capital', 'operate'],
#  'Trail': ['long', 'ton', 'smelter', 'produce', 'year'],
#  'Frans Andriessen': ['EC', 'say', 'Commissioner', 'minister', 'tax'],
#  'Santos': ['say', 'gas', 'exploration', 'oil', 'mln'],
#  'Gerhard\n  Stoltenberg': ['say', 'Monday', 'Finance', 'meeting', 'Baker'],
#  'Alan Greenspan': ['say', 'dollar', 'market', 'Chairman', 'inflation'],
#  'Treasurer Paul Keating': ['say', 'growth', 'economic', 'billion', 'account'],
#  'Ronald Perelman': ['Revlon', 'company', 'say', 'Gillette', 'Group'],
#  'L.F. Rothschild': ['say', 'Warburg', 'Pincus', 'official', 'price'],
#  'Lim Keng Yaik': ['new', 'Minister', 'say', 'Primary', 'Industries'],
#  'Hoare Govett': ['say', 'stockbroker', 'go', 'Richard', 'Jeffrey'],
#  'Mir-Hossein': ['iranian', 'Mousavi', 'Prime', 'Minister', 'Premier'],
#  'Diplomats': ['say', 'Iran', 'Iraq', 'minister', 'shell'],
#  'Boliden': ['operation', 'tell', 'Nilsson', 'Kjell', 'news'],
#  'Tadashi Kuranari': ['say', 'Foreign', 'Minister', 'official', 'Japan'],
#  'Rainbow': ['say', 'merger', 'share', 'Progressive', 'BIL'],
#  'Alejandro Martinez': ['producer', 'price', 'say', 'Minister', 'Cuenca'],
#  'Michael Jopling': ['EC', 'oil', 'say', 'minister', 'proposal'],
#  'AFG': ['Wagner', 'Brown', 'offer', 'GenCorp', 'Reynolds'],
#  'Pat Roberts': ['say', 'Kan', 'comment', 'administration', 'offer'],
#  'microchips': ['computer', 'United', 'States', 'Japan', 'accuse'],
#  'Delegates': ['say', 'buffer', 'stock', 'cocoa', 'negotiation'],
#  'Robert Ortner': ['say', 'dollar', 'currency', 'yen', 'Commerce'],
#  'Fairchild': ['say', 'company', 'buy', 'firm', 'Schlumberger'],
#  'Theodore Cross': ['share', 'investor', 'dlrs', 'Harper', 'Row'],
#  'John Herrington\n  ': ['oil', 'say', 'tax', 'House', 'increase'],
#  'Victor Paz Estenssoro': ['government',
#   'president',
#   'miner',
#   'willing',
#   'negotiate'],
#  'Wendy': ['say', 'rumor', 'believe', 'analyst', 'high'],
#  'Mike Moore': ['minister', 'great', 'say', 'tell', 'Trade'],
#  'Mutsuki Kato': ['Japan', 'Agriculture', 'Minister', 'say', 'farm'],
#  'Edmonton': ['site', 'Swann', 'Hills', 'ct', 'barrel'],
#  'kilos': ['dlrs', 'today', 'predict', 'Ecus', 'trader'],
#  'Karl Otto Poehl\n  ': ['say', 'Germany', 'West', 'rate', 'source'],
#  'Conrac': ['say', 'dlrs', 'company', 'Mark', 'IV'],
#  'Shintaro Abe': ['visit', 'April', 'LDP', 'executive', 'council'],
#  'Francisco Gros': ['bank', 'debt', 'negotiation', 'billion', 'dlrs'],
#  'Anderson': ['Comdata', 'Carson', 'Stowe', 'say', 'Network'],
#  'J.P. Morgan': ['mln', 'dlrs', 'say', 'Co', 'rate'],
#  'Rio Grande': ['low', 'state', 'Sao', 'Paulo', 'Parana'],
#  'Fleet': ['say', 'dlrs', 'Norstar', 'banking', 'law'],
#  'Kohlberg Kravis Roberts': ['Co', 'own', 'pct', 'Owens', 'Union'],
#  'Robert Heller': ['say', 'price', 'bank', 'monetary', 'american'],
#  'Claus Koehler': ['Bundesbank', 'board', 'member', 'say', 'cut'],
#  'Bahrain': ['dinar', 'bank', 'short', 'day', 'money'],
#  'Alex': ['Brown', 'Sons', 'Inc', 'company', 'say'],
#  'mln tonnes': ['crop', 'vs', 'month', 'Agriculture', 'Ministry'],
#  'Moore': ['say', 'acquisition', 'Sinclair', 'shareholder', 'resolution'],
#  'Ward McCarthy': ['Fed', 'say', 'Merrill', 'Lynch', 'week'],
#  'David Jones': ['say', 'rate', 'dollar', 'pct', 'Lanston'],
#  'Vincent Siew': ['tell', 'rise', 'reporter', 'face', 'talk'],
#  'David Annesley': ['Dome', 'spokesman', 'say', 'Mines', 'price'],
#  'Michel Noir': ['say', 'talk', 'Foreign', 'Trade', 'Minister'],
#  'Morgan': ['billion', 'say', 'mln', 'surplus', 'dlrs'],
#  'Williams': ['share', 'Norcros', 'mln', 'offer', 'hold'],
#  'palm olein': ['tonne', 'bleach', 'deodorise', 'shipment', 'trader'],
#  'Richard Darman': ['Baker', 'say', 'policy', 'official', 'Treasury'],
#  'Mariano Rubio': ['say', 'governor', 'central', 'bank', 'money'],
#  'Triton': ['say', 'pct', 'Shell', 'own', 'Europe'],
#  'Allan Leslie': ['say', 'Discount', 'consumer', 'rise', 'factor'],
#  'Conoco': ['Atlantic', 'Richfield', 'say', 'Petroleum', 'option'],
#  'Natalie Koether': ['say', 'stake', 'Inc', 'pct', 'shareholder'],
#  'Jose Romero': ['say', 'EC', 'oil', 'copra', 'coconut'],
#  'Reuters': ['tell', 'dutch', 'cocoa', 'processor', 'unhappy'],
#  'MLN STG': ['money', 'market', 'give'],
#  'Robert Maxwell': ['Harcourt', 'british', 'say', 'Plc', 'publisher'],
#  'Paul Bilzerian': ['say', 'share', 'company', 'offer', 'dlrs'],
#  'Crazy Eddie': ['company', 'group', 'financial', 'request', 'shareholder'],
#  'Allan Hawkins': ['say', 'ETL', 'statement', 'BIL', 'merger'],
#  'Helmut Schmidt': ['Poehl', 'Chancellor', 'Social', 'appoint', 'economist'],
#  'U.K. Economist': ['say', 'chief', 'Bill', 'Martin', 'Phillips'],
#  'Senegal': ['country', 'Nigeria', 'say', 'wheat', 'Indonesia'],
#  'Bass Strait': ['oil', 'output', 'gas', 'say', 'production'],
#  'N.Z. Dlrs': ['billion', 'say', 'predict', 'normal', 'mln'],
#  'Atlantic Richfield': ['say', 'divestiture', 'line', 'policy', 'focus'],
#  'Sanford C. Bernstein': ['say', 'earning', 'dlrs', 'Co', 'estimate'],
#  'Light Louisiana Sweet': ['raise', 'dlrs', 'ct', 'post', 'company'],
#  'Cargill Inc': ['tonne', 'Minnesota', 'take', 'shipment', 'price'],
#  'Lufkin': ['Jenrette', 'Donaldson', 'Securities', 'stock', 'Co'],
#  'Rosario Ilacqua': ['say', 'analyst', 'Rothschild', 'market', 'raise'],
#  'Karl-Heinz Narjes': ['say', 'EC', 'industry', 'minister', 'tell'],
#  'Carey': ['Woodhouse', 'Drake', 'market', 'say', 'weekly'],
#  'Jon Rosenbaum': ['say', 'quota', 'coffee', 'trade', 'representative'],
#  'Gencorp Inc': ['say', 'offer', 'general', 'tire', 'Tilden'],
#  'Pertamina': ['company', 'oil', 'say', 'state', 'Abdul'],
#  'Richard Jeffrey': ['say', 'go', 'Hoare', 'Govett', 'rate'],
#  'James Capel': ['say', 'worldwide', 'broker', 'comment', 'benefit'],
#  'Chang Chi-cheng': ['bank', 'say', 'reserve', 'local', 'central'],
#  'Phillips': ['say', 'dlrs', 'oil', 'Silas', 'billion'],
#  'Consumer': ['say', 'delegate', 'price', 'producer', 'Bra'],
#  'Bra Kanon': ['say', 'March', 'consumer', 'fulfil', 'duty'],
#  'Hanson': ['say', 'Cement', 'mln', 'dlrs', 'merger'],
#  'Jeumont-Schneider': ['Siemens', 'french', 'subsidiary', 'pct', 'West'],
#  'Acquisition': ['General', 'say', 'board', 'shareholder', 'GenCorp'],
#  'Hillards': ['share', 'Tesco', 'unchanged', 'pence', 'firmer'],
#  'Mannesmann': ['say', 'pct', 'stake', 'Sachs', 'Dieter'],
#  'Lindenberg Sette': ['say', 'producer', 'brazilian', 'delegate', 'market'],
#  'fl-yr': ['net', 'include', 'gain', 'mln', 'dlr'],
#  'Jerry Huckaby': ['sugar', 'say', 'program', 'year', 'production'],
#  'Greenmail': ['shareholder', 'premium', 'unwanted', 'payment', 'share'],
#  'T. Boone': ['Pickens', 'offer', 'dlrs', 'Texas', 'say'],
#  'Entre Rios': ['mm', 'Santa', 'Fe', 'province', 'rainfall'],
#  'Watanabe': ['say', 'company', 'new', 'C', 'share'],
#  'Bayou': ['dlrs', 'share', 'net', 'ct', 'pct'],
#  'Sumner Redstone': ['Viacom', 'say', 'offer', 'dlrs', 'group'],
#  'D-Vt.': ['Agriculture', 'Committee', 'Chairman', 'Senate', 'Patrick'],
#  'Refinery': ['mln', 'crude', 'run', 'week', 'bpd'],
#  'Iowa Beef': ['December', 'say', 'meatpacker', 'plant', 'mid'],
#  'Mark Buckstein': ['TWA', 'say', 'general', 'counsel', 'vice'],
#  'Gross': ['mln', 'vs', 'billion', 'rise', 'pct'],
#  'Balao': ['oil', 'km', 'jungle', 'field', 'Ecuador'],
#  'Johnson': ['say', 'Tate', 'Lyle', 'income', 'Food'],
#  'Maple Leaf': ['say', 'mln', 'dlrs', 'Canadian', 'Eagle'],
#  'Gelco': ['unit', 'sale', 'Canada', 'dlrs', 'say'],
#  'Saddam Hussein': ['say', 'President', 'cause', 'tension', 'Iraq'],
#  'Rachmat Saleh': ['oil', 'Indonesia', 'say', 'Trade', 'Minister'],
#  'Simon Smithson': ['say', 'grow', 'Kleinwort', 'Benson', 'financial'],
#  'Monier': ['say', 'ETL', 'bid', 'share', 'mln'],
#  'Makoto Kuroda': ['say', 'miti', 'Trade', 'leave', 'today'],
#  'Simon Keswick': ['say', 'Jardine', 'share', 'issue', 'chairman'],
#  'Eduardo Cojuangco': ['UCPB', 'share', 'represent', 'SMC', 'chairman'],
#  'Queensland': ['crop', 'say', 'pct', 'field', 'far'],
#  'Rains': ['week', 'province', 'Buenos', 'Aires', 'Cordoba'],
#  'Edouard\n  Balladur': ['Finance', 'pct', 'Minister', 'french', 'year'],
#  'Giovanni Goria': ['italian', 'say', 'Minister', 'Treasury', 'source'],
#  'Samuel Heyman': ['GAF', 'Borg', 'Warner', 'company', 'say'],
#  'Sul': ['pct', 'Mato', 'Grosso', 'nation', 'capacity'],
#  'Co Inc': ['dlrs', 'share', 'stock', 'Gabelli', 'investment'],
#  'Edward Johnson': ['pct', 'Redbook', 'say', 'Analyst', 'Associates'],
#  'Bruce Smart': ['Commerce', 'Trade', 'Undersecretary', 'say', 'gratified'],
#  'Allen Wallis': ['State', 'trade', 'meet', 'Undersecretary', 'say'],
#  'Williams Cos': ['dlrs', 'say', 'mln', 'sale', 'year'],
#  'Takashi Ishihara': ['chairman',
#   'Japan',
#   'Committee',
#   'Economic',
#   'Development'],
#  'Dieter Hiss': ['rate', 'cut', 'West', 'Berlin', 'state'],
#  'Poehl': ['say', 'rate', 'german', 'international', 'interest'],
#  'Asarco Inc': ['cent', 'say', 'price', 'lb', 'effective'],
#  'MM': ['ARGENTINE', 'GRAIN', 'BELT', 'TEMPERATURES', 'centigrade'],
#  'CHARLES DESTREHAN': ['RESERVE', 'ELEVATOR', 'CORP', 'PEAVEY', 'CO'],
#  'Aug': ['dlrs', 'Dec', 'stock', 'vs', 'month'],
#  'pct sulphur': ['dlrs', 'ct', 'dlr', 'increase', 'bring'],
#  'SUPPLY FALLS': ['money', 'billion', 'dlrs', 'MARCH', 'WEEK'],
#  'Douglas Danforth': ['say', 'Westinghouse', 'BP', 'chairman', 'special'],
#  'Aubrey G. Lanston': ['say', 'David', 'Jones', 'economist', 'Co'],
#  'Lago Agrio': ['pipeline', 'port', 'link', 'jungle', 'oilfield'],
#  'Yoweri Museveni': ['coffee', 'President', 'order', 'rail', 'cost'],
#  'Chris Tinker': ['phillip', 'year', 'Analyst', 'broker', 'economist'],
#  'Btu': ['dlrs', 'mln', 'gas', 'price', 'say'],
#  'Ralph Klopfenstein': ['price', 'wheat', 'USDA', 'cent', 'deputy'],
#  'Comalco': ['say', 'Goldendale', 'smelter', 'Columbia', 'Corp'],
#  'Charles Rose': ['say', 'GAF', 'Borg', 'Oppenheimer', 'Co'],
#  'Reynolds': ['say', 'expect', 'restart', 'begin', 'tonne'],
#  'Goodyear Tire': ['Co', 'say', 'Rubber', 'company', 'receive'],
#  'Junichiro Koizumi': ['plan', 'LDP', 'say', 'cut', 'tax'],
#  'Yasuhiro\n  ': ['Nakasone', 'Abe', 'visit', 'prepare', 'Prime'],
#  'Jaime Ongpin': ['Secretary', 'Finance', 'say', 'government', 'billion'],
#  'Jose Concepcion': ['Secretary', 'Trade', 'Industry', 'Philippines', 'tell'],
#  'Fitzwater': ['say', 'administration', 'Reagan', 'tax', 'hike'],
#  'Jeffrey Leeds': ['Chemical', 'Bank', 'Fed', 'policy', 'say'],
#  'Helmut\n  Schlesinger': ['say', 'Bundesbank', 'central', 'bank', 'pct'],
#  'Fahd': ['say', 'King', 'month', 'Saudi', 'Arabia'],
#  'Aramco': ['mln', 'barrel', 'contract', 'day', 'bpd'],
#  'John Lichtblau': ['say', 'Petroleum', 'Industry', 'Foundation', 'Research'],
#  'Bahia': ['mln', 'bag', 'say', 'crop', 'total'],
#  'Arne Oeien': ['Oil', 'Minister', 'Norway', 'production', 'tell'],
#  'Stark': ['iraqi', 'missile', 'attack', 'frigate', 'kill'],
#  'Peter Beutel': ['Elders', 'Futures', 'say', 'analyst', 'crude'],
#  'Larry Eckenfelder': ['say', 'Prudential', 'Bache', 'Express', 'American'],
#  'Atcor Inc': ['say', 'consumer', 'segment', 'Roth', 'American'],
#  'jack': ['say', 'rate', 'think', 'West', 'Germany'],
#  'Jones': ['Vining', 'say', 'share', 'Vulcan', 'dlrs'],
#  'Stephen Slifer': ['market', 'money', 'add', 'economist', 'Lehman'],
#  'Achmad Affandi': ['say', 'sugar', 'foreign', 'free', 'rice'],
#  'Nigeria': ['mln', 'bpd', 'say', 'OPEC', 'price'],
#  'Dale Mohler': ['say', 'inch', 'meteorologist', 'Accu', 'Weather'],
#  'Tom Harkin': ['pct', 'farm', 'say', 'high', 'price'],
#  'Monfort': ['pct', 'mln', 'share', 'ConAgra', 'company'],
#  'Rilwanu Lukman\n  ': ['say', 'OPEC', 'price', 'Opec', 'bpd'],
#  'John Shad': ['say', 'chairman', 'year', 'insider', 'trading'],
#  'Transco': ['gas', 'say', 'pipeline', 'open', 'access'],
#  'Martha Seger': ['say', 'Governor', 'Federal', 'Reserve', 'Board'],
#  'Brian Singer': ['say', 'range', 'oil', 'market', 'Carroll'],
#  'Hashemi Rafsanjani': ['Iran', 'say', 'Tehran', 'Radio', 'spokesman'],
#  'Peter Walters': ['BP', 'chairman', 'Sir', 'Standard', 'America'],
#  'Mahbubul Haq': ['say', 'year', 'Commerce', 'Minister', 'import'],
#  'Stephen Roach': ['pct', 'rise', 'quarter', 'say', 'rate'],
#  'Kellogg': ['say', 'capacity', 'pct', 'instal', 'cost'],
#  'Arturo': ['oil', 'price', 'despite', 'iranian', 'platform'],
#  'Hernandez Grisanti': ['say', 'market', 'oil', 'price', 'meeting'],
#  'Sumita': ['welcome', 'german', 'joint', 'confirmation', 'Louvre'],
#  'Buffer': ['stock', 'purchase', 'cocoa', 'future', 'manager'],
#  'Mousavi': ['Tehran', 'say', 'retaliate', 'properly', 'perfidious'],
#  'Schlumberger': ['Iran', 'service', 'extraordinary', 'item', 'mln'],
#  'Norsk Hydro': ['say', 'operator', 'field', 'production', 'bpd'],
#  'Richard Lugar': ['say', 'law', 'Republican', 'Senate', 'Agriculture'],
#  'Young': ['say', 'Defense', 'Secretary', 'Caspar', 'Weinberger'],
#  'Belzberg': ['family', 'Canada', 'Sprint', 'Bregman', 'Partners'],
#  'Woolworth': ['say', 'share', 'pct', 'percent', 'own'],
#  'James\n  Baker': ['Treasury', 'Secretary', 'say', 'rate', 'increase'],
#  'Hirozumi Tanaka': ['say', 'Dai', 'Kangyo', 'Ichi', 'assistant'],
#  'Cesar Gaviria': ['finance', 'minister', 'talk', 'say', 'colombian'],
#  'David Roderick': ['say', 'USX', 'dollar', 'trade', 'Corp'],
#  'Francois Guillaume': ['french', 'minister', 'Minister', 'propose', 'say'],
#  'Jaime Lusinchi': ['President', 'Caracas', 'say', 'Venezuela', 'loan'],
#  'Canamax': ['say', 'gold', 'ounce', 'Pacific', 'Trans'],
#  'Countertrade': ['account', 'pct', 'India', 'billion', 'dlrs'],
#  'Haruo Maekawa': ['report', 'Japan', 'say', 'point', 'Europeans'],
#  'Paul Collins': ['BIL', 'Rainbow', 'share', 'say', 'merger'],
#  'Peter Baron': ['consumer', 'spokesman', 'buffer', 'stock', 'rule'],
#  'Shoichi Saba': ['agreement',
#   'Chairman',
#   'comply',
#   'japanese',
#   'semiconductor'],
#  'Turgut Ozal': ['Prime', 'Minister', 'night', 'water', 'vessel'],
#  'Tian Jiyun': ['say', 'fec', 'consider', 'chinese', 'Vice'],
#  'Alan Garcia': ['say', 'gold', 'deposit', 'mln', 'Peru'],
#  'Jardine Fleming': ['say', 'mln', 'sure', 'miti', 'benefit'],
#  'Tom Murtha': ['say', 'analyst', 'James', 'Capel', 'tariff'],
#  'Carole Ryavec': ['analyst', 'Brothers', 'Asia', 'Salomon', 'Ltd'],
#  'Archie Dunham': ['say', 'level', 'product', 'crude', 'oil'],
#  'Henry Rosenberg': ['Crown', 'chairman', 'Central', 'Petroleum', 'grade'],
#  'Dennis McAlpine': ['say', 'Oppenheimer', 'analyst', 'Co', 'investor'],
#  'Robert\n  Byrd': ['Senate', 'Democratic', 'Leader', 'tell', 'want'],
#  'Philip Braverman': ['say', 'portfolio', 'Irving', 'Securities', 'run'],
#  'Hutchison': ['group', 'Hongkong', 'provide', 'share', 'Electric'],
#  'Raul Gardini': ['Ferruzzi', 'say', 'CPC', 'business', 'European'],
#  'D-La': ['loan', 'Jerry', 'Huckaby', 'year', 'sweetener'],
#  'Gruppo Ferruzzi': ['Sugar', 'mln', 'share', 'pct', 'french'],
#  'Jean-Marc Vernes': ['say', 'Beghin', 'president', 'possible', 'EC'],
#  'Jacques Chirac\n  ': ['say', 'french', 'France', 'Minister', 'Reagan'],
#  'Craig Sloane': ['say', 'analyst', 'currency', 'Smith', 'Barney'],
#  'Walter Seipp': ['management', 'board', 'chairman', 'rate', 'say'],
#  'Kjell Nilsson': ['operation', 'boliden', 'mining', 'tell', 'news'],
#  'Samuel Montagu': ['market', 'Co', 'Ltd', 'say', 'climate'],
#  'Bert Duim': ['union', 'employer', 'spokesman', 'say', 'strike'],
#  'Chuck Levitt': ['Shearson', 'Lehman', 'analyst', 'say', 'hog'],
#  'Roger Hemminghaus': ['Diamond', 'Shamrock', 'refining', 'say', 'marketing'],
#  'Diamond Shamrock': ['New', 'York', 'Stock', 'Exchange', 'trading'],
#  'Arkadi Kuhlmann': ['Deak', 'metal', 'president', 'chief', 'executive'],
#  'Buenos Aires': ['mm', 'area', 'province', 'fall', 'February'],
#  'Aero': ['dlrs', 'Dynalectron', 'operate', 'plan', 'Dynair'],
#  'Doresy Gardner': ['say', 'company', 'director', 'sell', 'Purolator'],
#  'Sandra Kaul': ['coffee', 'analyst', 'Shearson', 'year', 'producer'],
#  'Sunflowerseed': ['total', 'cake', 'expeller', 'pellet', 'meal'],
#  'Glenn': ['D', 'English', 'amendment', 'offer', 'say'],
#  'Alfred Herrhausen': ['say', 'Deutsche', 'board', 'joint', 'spokesman'],
#  'Degussa': ['pct', 'MIM', 'say', 'exploration', 'International'],
#  'Steve Slifer': ['say', 'Lehman', 'Government', 'Securities', 'drop'],
#  'Ecopetrol': ['oil', 'say', 'state', 'run', 'company'],
#  'John Melcher': ['D', 'Mont', 'measure', 'trade', 'bill'],
#  'D-Mont': ['John', 'Melcher', 'measure', 'Chairman', 'trade'],
#  'Co': ['dlrs', 'Japan', 'sell', 'estimate', 'share'],
#  'Edward Zorinsky': ['D', 'Neb', 'say', 'crop', 'practice'],
#  'D-Neb': ['Edward', 'Zorinsky', 'say', 'crop', 'practice'],
#  'Paul Mlotok': ['say', 'oil', 'analyst', 'Salomon', 'Brothers'],
#  'Jersey': ['Ward', 'billion', 'lawyer', 'tell', 'court'],
#  'Lambert Inc': ['Drexel', 'Burnham', 'Wall', 'say', 'senior'],
#  'Rainfall': ['mm', 'province', 'Buenos', 'Aires', 'heavy'],
#  'Rudy Boschwitz': ['Minn', 'say', 'intend', 'offer', 'producer'],
#  'Comdata': ['say', 'dlrs', 'stock', 'security', 'company'],
#  'Albert Melnikov': ['say', 'agreement', 'price', 'United', 'States'],
#  'Gerhard de Kock': ['rand', 'rise', 'billion', 'Reserve', 'Bank'],
#  'Gaviria': ['say', 'price', 'coffee', 'export', 'low'],
#  'Ike Kerridge': ['say', 'Hughes', 'vice', 'president', 'recommendation'],
#  'Charles Grassley': ['R', 'Iowa', 'import', 'producer', 'say'],
#  'Thad Cochran': ['R', 'Miss', 'loan', 'marketing', 'producer'],
#  'Halcyon': ['say', 'buy', 'dlrs', 'mln', 'share'],
#  'Stephen Lewis': ['say', 'rate', 'Drew', 'point', 'society'],
#  'Hughes': ['merger', 'say', 'Baker', 'Reed', 'business'],
#  'Ali al-Khalifa al-Sabah': ['Sheikh', 'daily', 'Qabas', 'say', 'OPEC'],
#  'D-Kan': ['feedgrain', 'subcommittee', 'chairman', 'Dan', 'Glickman'],
#  'Harold Simmons': ['pct', 'International', 'Dallas', 'investor', 'tell'],
#  'LeRoy Pesch': ['shareholder', 'say', 'discussion', 'AMI', 'Chicago'],
#  'Peter Greenbaum': ['Smith', 'Barney', 'Harris', 'Upham', 'Co'],
#  'Ian Harwood': ['say', 'cut', 'economist', 'Warburg', 'Securities'],
#  'Bancroft': ['say', 'Zico', 'share', 'offer', 'tender'],
#  'George Soros': ['say', 'investor', 'group', 'company', 'share'],
#  'Zeebrugge': ['ferry', 'Dover', 'capsize', 'believe', 'trap'],
#  'Daniel Lee': ['analyst', 'Drexel', 'Burnham', 'say', 'stock'],
#  'Marcel Masse': ['oil', 'Minister', 'say', 'company', 'Energy'],
#  'Zico': ['offer', 'Bancroft', 'share', 'say', 'tender'],
#  'Arifin Siregar': ['governor', 'say', 'Indonesia', 'economic', 'Central'],
#  'Rexnord': ['say', 'sale', 'major', 'program', 'divest'],
#  'R-Kan': ['say', 'republican', 'Pat', 'Roberts', 'farm'],
#  'Renouf': ['say', 'unit', 'hold', 'build', 'NZI'],
#  'Ernest Saunders': ['Ward', 'company', 'Guinness', 'say', 'Jersey'],
#  'Baird': ['Mark', 'IV', 'pct', 'say', 'stock'],
#  'Allen Zack': ['say', 'spokesman', 'Iowa', 'Beef', 'UFCW'],
#  'Derrick Holden-Brown': ['say', 'Allied', 'Lyons', 'chairman', 'distiller'],
#  'Hans Jucker': ['say', 'year', 'loss', 'Alusuisse', 'chief'],
#  'Wayne Bennett': ['say', 'producer', 'soybean', 'EC', 'president'],
#  'Grootvlei': ['say', 'gold', 'General', 'Union', 'Mining'],
#  'Sheikh Ali\n  al-Khalifa al-Sabah': ['OPEC',
#   'oil',
#   'Kuwaiti',
#   'say',
#   'output'],
#  'Roy Denman': ['trade', 'say', 'EC', 'Rostenkowski', 'tell'],
#  'James E. Olson': ['say', 'chairman', 'T', 'cts', 'share'],
#  'John Dawkins': ['Trade', 'say', 'trade', 'australian', 'Minister'],
#  'Ardeshir': ['iraqi', 'warplane', 'strike', 'Iran', 'offshore'],
#  'Hecla': ['zinc', 'ore', 'ton', 'say', 'production'],
#  'David\n  Mulford': ['nation', 'say', 'exchange', 'Germany', 'international'],
#  'Kim Mahn-je': ['surplus', 'say', 'government', 'trade', 'current'],
#  'Michael Armacost': ['Secretary', 'State', 'political', 'affair', 'ask'],
#  'Sheikh Ali al-Khalifa al-Sabah': ['say',
#   'OPEC',
#   'bpd',
#   'Kuwait',
#   'production'],
#  'Asahi Shimbun': ['daily', 'bank', 'plan', 'billion', 'yen'],
#  'Jardine Matheson': ['say', 'share', 'issue', 'Hong', 'Kong'],
#  'Gerard Zeebregts': ['employer', 'say', 'procedure', 'Rotterdam', 'general'],
#  'William Proxmire': ['Senate',
#   'Banking',
#   'Committee',
#   'corporate',
#   'takeover'],
#  'Carson': ['say', 'dlrs', 'sell', 'subsidiary', 'source'],
#  'Paul Oreffice': ['say', 'Dow', 'Chemical', 'Co', 'poise'],
#  'Asher\n  ': ['Edelman', 'buy', 'stake', 'company', 'consider'],
#  'Datron': ['officer', 'hold', 'pct', 'total', 'common'],
#  'Alexander': ['investment', 'firm', 'Vik', 'Trump', 'Interstate'],
#  'Tunisia': ['tonne', 'french', 'soft', 'wheat', 'export'],
#  'Nazmi Akiman': ['greek', 'Turkey', 'ambassador', 'meet', 'Prime'],
#  'Showboat Inc': ['Houssels', 'say', 'interest', 'charge', 'quarter'],
#  'Donald Houston': ['administrator', 'USDA', 'Food', 'Safety', 'Inspection'],
#  'Timothy Pettee': ['say', 'Bear', 'Stearns', 'analyst', 'exptect'],
#  'IRNA': ['say', 'Iran', 'agreement', 'provide', 'technical'],
#  'Kenneth Blaylock': ['inspection',
#   'American',
#   'Federation',
#   'Government',
#   'Employees'],
#  'Charles Stenholm': ['D', 'bill', 'Subcommittee', 'Chairman', 'Tex'],
#  'Richard Henderson': ['say', 'analyst', 'visualize', 'want', 'Donaldson'],
#  'Jeffrey Wendel': ['group', 'share', 'pct', 'say', 'Zondervan'],
#  'Christopher Moran': ['group', 'investor', 'London', 'year', 'Zondervan'],
#  'Strata': ['share', 'common', 'say', 'mln', 'merger'],
#  'Pat Carney': ['trade', 'Canada', 'steel', 'Trade', 'say'],
#  'Stewart': ['coffee', 'company', 'say', 'Superior', 'exclusive'],
#  'Johnson Matthey': ['own', 'Rustenburg', 'today', 'issue', 'follow'],
#  'Gisela Steinhaeuser': ['dollar', 'likely', 'stay', 'range', 'mark'],
#  'Theodor Stadelmann': ['dealer', 'Bank', 'Julius', 'Baer', 'Co'],
#  'Dave Jouhin': ['senior', 'dealer', 'Midland', 'Bank', 'London'],
#  'Todd': ['say', 'Galveston', 'April', 'Council', 'prefer'],
#  'Karl Otto': ['rate', 'Bundesbank', 'dollar', 'cut', 'aside'],
#  'Reichhold': ['say', 'right', 'share', 'stock', 'adoption'],
#  'Rexham': ['Nortek', 'say', 'share', 'pct', 'plan'],
#  'Bill Englebright': ['secretary', 'joint', 'LPFA', 'say', 'tier'],
#  'ST ELMO': ['CHARLES', 'DESTREHAN', 'RESERVE', 'ELEVATOR', 'CORP'],
#  'PORT ALLEN': ['CARGILL', 'GRAIN', 'TERRE', 'HAUTE'],
#  'Foothill': ['say', 'Santa', 'Cruz', 'pct', 'Inc'],
#  'Easter': ['April', 'analyst', 'generally', 'average', 'sale'],
#  'Jeff Edelman': ['analyst', 'number', 'consumer', 'say', 'Drexel'],
#  'William Howell': ['strong', 'penney', 'chairman', 'say', 'sale'],
#  'Zimbabwean': ['potentially', 'worth', 'mln', 'dlrs', 'year'],
#  'Cape Spencer': ['ton', 'say', 'geologist', 'locate', 'mln'],
#  'Gordex': ['say', 'expansion', 'Cape', 'Spencer', 'facility'],
#  'John Porter': ['R', 'Ill', 'introduce', 'House', 'Representatives'],
#  'R-Ill.': ['Porter', 'legislation', 'John', 'introduce', 'House'],
#  'Coniston': ['Allegis', 'comment', 'group', 'say', 'decline'],
#  'Warren Jestin': ['say', 'optimistic', 'outlook', 'give', 'fact'],
#  'mln bu': ['Usage', 'Haggard', 'say', 'bar', 'program'],
#  'Fluorocarbon Co': ['say', 'division', 'Eaton', 'Corp', 'mln'],
#  'Shamrock': ['share', 'say', 'Nawara', 'hold', 'Holly'],
#  'Sealy Inc': ['company', 'pct', 'say', 'outstanding', 'stock'],
#  'Strict Low Middling': ['Agriculture',
#   'Department',
#   'announce',
#   'prevail',
#   'world'],
#  'Float': ['dlrs', 'range', 'mln', 'Thursday', 'billion'],
#  'Gabelli': ['say', 'Exchange', 'investment', 'plan', 'Inc'],
#  'William Sullivan': ['say', 'Fed', 'firm', 'Dean', 'Witter'],
#  'Larry Leuzzi': ['say', 'Warburg', 'Co', 'clear', 'Fed'],
#  'Wang Der-Hwa': ['Deputy', 'Director', 'Finance', 'Ministry', 'Customs'],
#  'Michael Howard': ['say', 'Japan', 'visit', 'Corporate', 'Affairs'],
#  'Carlos Dominguez': ['Agriculture', 'Secretary', 'say', 'hope', 'loss'],
#  'Janos Fekete': ['say', 'billion', 'plan', 'central', 'banker'],
#  'George Gordon Paton': ['Co', 'Inc', 'report'],
#  'Doug Gowland': ['oil', 'say', 'restructuring', 'analyst', 'Brown'],
#  'Morris': ['share', 'dlrs', 'buy', 'stake', 'own'],
#  'Kenya': ['pct', 'devalue', 'shilling', 'special', 'drawing'],
#  'Het Comite': ['levy', 'animal', 'feed', 'grain', 'association']}

# %%
organization_most_popular_terms
# Out:
# {'mln': ['dlrs', 'say', 'share', 'year', 'net'],
#  'cts': ['vs', 'loss', 'Shr', 'profit', 'shr'],
#  'pct': ['say', 'rise', 'year', 'January', 'February'],
#  'QTR': ['net', 'loss', 'SHR', 'dlrs', 'CTS'],
#  'Reuters': ['tell', 'official', 'say', 'spokesman', 'year'],
#  'EC': ['say', 'export', 'trade', 'European', 'Community'],
#  'MLN': ['dlrs', 'DLRS', 'stg', 'say', 'WEEK'],
#  'USDA': ['say', 'mln', 'tonne', 'official', 'corn'],
#  'QTR NET\n  ': ['INC', 'CORP', 'INDUSTRIES', 'dlrs', 'vs'],
#  'Treasury': ['say', 'billion', 'Secretary', 'dlrs', 'Baker'],
#  'FED': ['say', 'set', 'billion', 'CUSTOMER', 'REPURCHASE'],
#  'the Securities and Exchange Commission': ['share',
#   'say',
#   'filing',
#   'dlrs',
#   'common'],
#  'PCT': ['rate', 'BANK', 'prime', 'rise', 'cuts'],
#  'QTR NET': ['dlrs', 'vs', 'shr', 'ct', 'CORP'],
#  'Fed': ['say', 'pct', 'dlrs', 'reserve', 'rate'],
#  'Congress': ['say', 'trade', 'bill', 'Reagan', 'administration'],
#  'The Bank of England': ['say', 'stg', 'mln', 'market', 'money'],
#  'OPEC': ['say', 'oil', 'price', 'bpd', 'mln'],
#  'Bank': ['stg', 'mln', 'say', 'billion', 'today'],
#  'Bundesbank': ['say', 'rate', 'billion', 'mark', 'money'],
#  'CTS': ['VS', 'SHR', 'QTR', 'say', 'INC'],
#  'qtr': ['dlrs', 'include', 'ct', 'vs', 'mln'],
#  'Co': ['say', 'company', 'share', 'mln', 'dlrs'],
#  'European Community': ['EC', 'say', 'tonne', 'sugar', 'export'],
#  'GATT': ['trade', 'say', 'Trade', 'General', 'Tariffs'],
#  'Oper': ['shr', 'dlrs', 'vs', 'mln', 'ct'],
#  'House': ['trade', 'bill', 'say', 'year', 'Reagan'],
#  'treasury': ['bill', 'mln', 'stg', 'bank', 'billion'],
#  'Senate': ['say', 'bill', 'House', 'tell', 'Japan'],
#  'QTR\n  ': ['SEES', 'INC', 'cost', 'WESTMINSTER', 'BANK'],
#  'CCC': ['say', 'Credit', 'Commodity', 'Corporation', 'sale'],
#  'The Federal Reserve': ['say',
#   'market',
#   'security',
#   'government',
#   'repurchase'],
#  'The U.S. Agriculture Department': ['tonne', 'mln', 'say', 'wheat', 'crop'],
#  'ICO': ['quota', 'say', 'export', 'coffee', 'producer'],
#  'SEC': ['say', 'filing', 'company', 'share', 'offer'],
#  'Bank of Japan': ['dollar', 'say', 'yen', 'dealer', 'Sumita'],
#  'NET': ['MLN', 'QTR', 'dlrs', 'FEB', 'MARCH'],
#  'the European Community': ['say', 'EC', 'year', 'export', 'market'],
#  'TREASURY': ['BAKER', 'SAYS', 'say', 'balance', 'SEES'],
#  'Agriculture': ['Secretary', 'Lyng', 'say', 'Richard', 'Minister'],
#  'Commission': ['say', 'EC', 'tonne', 'tax', 'price'],
#  'U.S. Treasury': ['say', 'James', 'Baker', 'Secretary', 'rate'],
#  'Commerce': ['Secretary', 'say', 'Malcolm', 'Baldrige', 'official'],
#  'Finance': ['Minister', 'say', 'year', 'pct', 'government'],
#  'Kuwaiti': ['tanker', 'say', 'oil', 'Gulf', 'escort'],
#  'OECD': ['say', 'pct', 'year', 'growth', 'rise'],
#  'The Bank of Japan': ['say', 'dollar', 'buy', 'dealer', 'yen'],
#  'the U.S. Agriculture Department': ['say',
#   'tonne',
#   'Credit',
#   'sale',
#   'wheat'],
#  'Federal Reserve Board': ['say', 'Chairman', 'Paul', 'Volcker', 'dollar'],
#  'the Federal Reserve': ['say', 'dlrs', 'dollar', 'week', 'billion'],
#  'the Securities and Exchange\n  Commission': ['tell',
#   'Inc',
#   'pct',
#   'say',
#   'share'],
#  'Merrill Lynch': ['say', 'dlrs', 'mln', 'Co', 'Inc'],
#  'the Bank of England': ['say', 'rate', 'market', 'signal', 'base'],
#  'State': ['Secretary', 'George', 'say', 'Shultz', 'official'],
#  'Co Inc': ['say', 'mln', 'Morgan', 'dlrs', 'company'],
#  'Parliament': ['tell', 'House', 'Lower', 'Committee', 'rate'],
#  'White House': ['say', 'spokesman', 'Marlin', 'Fitzwater', 'trade'],
#  'USAir': ['say', 'TWA', 'share', 'Piedmont', 'offer'],
#  'BP': ['say', 'Standard', 'pct', 'share', 'offer'],
#  'Finance Ministry': ['say', 'official', 'rate', 'pct', 'spokesman'],
#  'Community': ['EC', 'say', 'trade', 'export', 'billion'],
#  'the Bank of Japan': ['say', 'bank', 'rate', 'yen', 'dollar'],
#  'Lyng': ['say', 'wheat', 'export', 'offer', 'aide'],
#  'Energy': ['say', 'oil', 'Minister', 'Secretary', 'year'],
#  'the\n  Securities and Exchange Commission': ['pct',
#   'share',
#   'tell',
#   'total',
#   'Corp'],
#  'The European Community': ['EC', 'trade', 'say', 'tonne', 'United'],
#  'the World Bank': ['say', 'International', 'dlrs', 'mln', 'Monetary'],
#  'Nakasone': ['say', 'Japan', 'trade', 'japanese', 'Reagan'],
#  'the U.S. Agriculture\n  Department': ['say',
#   'Credit',
#   'Commodity',
#   'Corporation',
#   'CCC'],
#  'CTS\n  \n\n': ['VS', 'raise', 'loss', 'qtly', 'dividend'],
#  'Sumita': ['say', 'dollar', 'Japan', 'yen', 'cooperate'],
#  'TWA': ['USAir', 'say', 'offer', 'application', 'stock'],
#  'SETS': ['QUARTERLY', 'PAYOUT', 'INC', 'CORP', 'stock'],
#  'Central Bank': ['billion', 'rate', 'say', 'dollar', 'April'],
#  'The Commodity Credit Corporation': ['say',
#   'sale',
#   'Department',
#   'Agriculture',
#   'CCC'],
#  'MITI': ['say', 'official', 'chip', 'japanese', 'maker'],
#  'Group': ['mln', 'vs', 'billion', 'net', 'profit'],
#  'QTR OPER NET\n  ': [],
#  'Shell': ['say', 'mln', 'dlrs', 'oil', 'product'],
#  'the Finance Ministry': ['billion', 'say', 'pct', 'year', 'surplus'],
#  'World Bank': ['say', 'IMF', 'meeting', 'government', 'Zambia'],
#  'Chrysler': ['say', 'Renault', 'dlrs', 'share', 'amc'],
#  'Miyazawa': ['say', 'rate', 'nation', 'major', 'yen'],
#  'GenCorp': ['say', 'General', 'share', 'offer', 'dlrs'],
#  'the U.S.\n  Agriculture Department': ['say',
#   'sale',
#   'Credit',
#   'mln',
#   'corn'],
#  'Group of Seven': ['say', 'currency', 'Paris', 'meeting', 'industrial'],
#  'Cyclops': ['share', 'say', 'dlrs', 'offer', 'Dixons'],
#  'central bank': ['mln', 'say', 'pct', 'billion', 'today'],
#  'IBC': ['say', 'Coffee', 'Institute', 'Brazilian', 'export'],
#  'Statistics Canada': ['pct', 'say', 'rise', 'dlrs', 'January'],
#  'the European\n  Community': ['EC', 'say', 'import', 'oil', 'tax'],
#  'Cyclops Corp': ['say', 'share', 'Group', 'tender', 'pct'],
#  'Congressional': ['say', 'source', 'budget', 'cut', 'trade'],
#  'the EC Commission': ['minister', 'say', 'tax', 'oil', 'Community'],
#  'Bankers': ['say', 'bank', 'market', 'money', 'rate'],
#  'Shearson Lehman Brothers': ['say', 'market', 'sell', 'Co', 'company'],
#  'Shearson': ['say', 'Express', 'American', 'mln', 'market'],
#  'Cable': ['Wireless', 'Plc', 'say', 'pct', 'japanese'],
#  'EMS': ['say', 'currency', 'mark', 'rate', 'system'],
#  'Silkworm': ['missile', 'Iran', 'say', 'Gulf', 'ship'],
#  'the International Monetary Fund': ['Bank',
#   'meeting',
#   'say',
#   'annual',
#   'World'],
#  '1986/87': ['mln', 'tonne', 'grain', 'estimate', 'IWC'],
#  'Foreign Ministry': ['official', 'say', 'tell', 'statement', 'spokesman'],
#  'The Commodity Credit Corporation\n  ': ['sale',
#   'CCC',
#   'Agriculture',
#   'Department',
#   'say'],
#  'Dealers': ['say', 'Federal', 'fund', 'trade', 'pct'],
#  'the Commerce Department': ['pct', 'say', 'seasonally', 'mln', 'rise'],
#  'Citicorp': ['say', 'dlrs', 'share', 'Cyclops', 'offer'],
#  'INRA': ['new', 'price', 'say', 'Agreement', 'International'],
#  'Dixons': ['Cyclops', 'say', 'share', 'offer', 'tender'],
#  'Citibank': ['rate', 'prime', 'follow', 'say', 'pct'],
#  'MARCH': ['pct', 'rise', 'March', 'say', 'Treasury'],
#  'Purolator': ['say', 'share', 'Hutton', 'offer', 'pct'],
#  'GENCORP &lt;GY': ['GENERAL', 'partner', 'cuts', 'stake', 'group'],
#  'mln\n  ': ['share', 'say', 'common', 'purchase', 'dlrs'],
#  'Defense': ['Secretary', 'Caspar', 'Weinberger', 'say', 'Iran'],
#  'the Federal\n  Reserve': ['dlrs', 'billion', 'Treasury', 'say', 'balance'],
#  'the White House': ['say', 'japanese', 'oil', 'country', 'include'],
#  'UAE': ['United', 'Arab', 'Emirates', 'Arabia', 'Kuwait'],
#  'The Commerce Department': ['billion', 'dlrs', 'say', 'pct', 'report'],
#  'Pentagon': ['say', 'Gulf', 'ship', 'official', 'iranian'],
#  'Piedmont': ['share', 'USAir', 'say', 'offer', 'pct'],
#  'EEP': ['say', 'wheat', 'offer', 'export', 'program'],
#  'Sterling': ['dlrs', 'say', 'market', 'high', 'rate'],
#  'Taft': ['say', 'share', 'company', 'group', 'offer'],
#  'The U.S. Agriculture Department\n  ': ['tonne',
#   'mln',
#   'price',
#   'announce',
#   'forecast'],
#  'Inc': ['say', 'dlrs', 'pct', 'group', 'mln'],
#  'UNIT\n  ': ['sell', 'ELECTROHOME', 'BUY', 'TEXAS', 'AMERICAN'],
#  'Petrobras': ['oil', 'say', 'company', 'Brazil', 'state'],
#  'the China Daily': ['say', 'wheat', 'crop', 'mln', 'open'],
#  'Trade': ['say', 'trade', 'Representative', 'Minister', 'Clayton'],
#  'Agriculture Ministry': ['say', 'official', 'mln', 'tonne', 'Japan'],
#  'Continental': ['say', 'dlrs', 'mln', 'share', 'stock'],
#  'Dome': ['say', 'dlrs', 'TransCanada', 'billion', 'share'],
#  'The Commission': ['say', 'year', 'industry', 'EC', 'intervention'],
#  'Hutton': ['say', 'offer', 'share', 'Purolator', 'tender'],
#  'the U.S. Congress': ['say', 'trade', 'bill', 'protectionist', 'Reagan'],
#  'Customs': ['figure', 'tonne', 'mln', 'import', 'say'],
#  'Wireless': ['Cable', 'japanese', 'pct', 'say', 'stake'],
#  'USAIR &lt;U': ['TWA', 'DOT', 'DISMISSES', 'PS', 'GROUP'],
#  'USAir Group Inc': ['say', 'share', 'Piedmont', 'Aviation', 'Airlines'],
#  'the Central Bank': ['billion', 'pct', 'rate', 'say', 'rise'],
#  'the\n  European Community': ['EC', 'say', 'import', 'United', 'States'],
#  'Liberal Democratic Party': ['Japan', 'LDP', 'rule', 'measure', 'say'],
#  'MALAYSIA': ['RISE', 'rubber', 'RUBBER', 'meet', 'SEEKS'],
#  'Group of Five': ['Canada', 'meeting', 'say', 'February', 'rate'],
#  'The EC Commission': ['export', 'say', 'tonne', 'import', 'tender'],
#  'the New York Stock Exchange': ['say', 'share', 'delist', 'sell', 'result'],
#  'MATURITY': ['day', 'pct', 'RATE', 'OLD', 'rate'],
#  'Exxon': ['say', 'refinery', 'dlrs', 'billion', 'oil'],
#  'Federal Reserve': ['Paul', 'Volcker', 'say', 'week', 'policy'],
#  'CPC': ['say', 'business', 'mln', 'dlrs', 'Ferruzzi'],
#  'USAir Group': ['TWA', 'Airlines', 'say', 'Inc', 'Trans'],
#  'AMC': ['Chrysler', 'Renault', 'say', 'dlrs', 'mln'],
#  'the Reserve Bank': ['pct', 'say', 'billion', 'January', 'rise'],
#  'the Securities\n  and Exchange Commission': ['share',
#   'say',
#   'pct',
#   'file',
#   'tell'],
#  'LME': ['contract', 'say', 'delivery', 'new', 'Metal'],
#  'Ferruzzi': ['CPC', 'say', 'mln', 'Sugar', 'business'],
#  'Council': ['say', 'year', 'chairman', 'pct', 'member'],
#  'CRUDE': ['MLN', 'GASOLINE', 'bbl', 'distillate', 'stock'],
#  'Budget': ['say', 'election', 'government', 'forecast', 'general'],
#  'CSR': ['say', 'bid', 'pct', 'offer', 'Pioneer'],
#  'Noranda': ['say', 'operate', 'fire', 'operation', 'Quebec'],
#  'The Federal Home Loan Bank Board\n  ': ['adjust',
#   'rate',
#   'short',
#   'term',
#   'discount'],
#  "the U.S. Agriculture Department's": ['report',
#   'say',
#   'field',
#   'grain',
#   'officer'],
#  'SOLD': ['exporters', 'unknown', 'corn', 'report', 'REPORT'],
#  'General Partners': ['GenCorp', 'say', 'share', 'offer', 'dlrs'],
#  'Farmers': ['dlrs', 'say', 'billion', 'payment', 'crop'],
#  'Balladur': ['say', 'pct', 'accord', 'Louvre', 'year'],
#  'GRAIN': ['ship', 'LOADING', 'SHIPS', 'SHIPMENTS', 'USSR'],
#  'the Federal Statistics Office': ['pct',
#   'say',
#   'February',
#   'January',
#   'price'],
#  'Loan Association': ['Savings', 'Federal', 'say', 'Financial', 'acquire'],
#  'E.F. Hutton': ['say', 'dlrs', 'Inc', 'mln', 'company'],
#  'CTS VS': ['loss', 'CORP', 'PROFIT', 'YEAR', 'SHR'],
#  'Opec': ['say', 'price', 'output', 'oil', 'member'],
#  'Morgan Stanley': ['say', 'Burlington', 'Co', 'group', 'dlrs'],
#  'CYCLOPS &lt;CYL': ['market', 'OPPENHEIMER', 'pct', 'jefferie', 'makes'],
#  'Agriculture Department': ['say', 'official', 'year', 'crop', 'mln'],
#  'GenCorp Inc': ['say', 'company', 'offer', 'board', 'share'],
#  'Goldman Sachs': ['Co', 'say', 'share', 'buyer', 'issue'],
#  'GAF': ['offer', 'say', 'share', 'Borg', 'Warner'],
#  'Ministry': ['say', 'billion', 'spokesman', 'dlrs', 'January'],
#  'Edelman': ['say', 'company', 'Dominion', 'Burlington', 'Lucky'],
#  'The White House': ['say', 'tax', 'proposal', 'code', 'trade'],
#  'GMT': ['dlrs', 'bank', 'bid', 'today', 'tomorrow'],
#  'United': ['share', 'say', 'Norstar', 'stock', 'mln'],
#  'the Reagan Administration': ['say', 'oil', 'increase', 'report', 'tax'],
#  'Administration': ['say', 'official', 'increase', 'policy', 'deficit'],
#  'Bank of Canada': ['dlrs', 'say', 'week', 'billion', 'end'],
#  'U.S. Agriculture Department': ['say',
#   'dlrs',
#   'official',
#   'mln',
#   'guarantee'],
#  'National Bank': ['rate', 'say', 'spokesman', 'economic', 'money'],
#  'Borg-Warner': ['say', 'offer', 'share', 'board', 'company'],
#  'Sosnoff': ['Caesars', 'say', 'offer', 'World', 'share'],
#  'Allied': ['say', 'Campeau', 'dlrs', 'mln', 'sale'],
#  'Borg-Warner Corp': ['say', 'GAF', 'offer', 'dlrs', 'share'],
#  'Standard Oil Co': ['say', 'pct', 'British', 'Petroleum', 'billion'],
#  'Oppenheimer': ['say', 'share', 'Co', 'analyst', 'dlrs'],
#  'Shearson Lehman Brothers Inc': ['Co',
#   'say',
#   'American',
#   'Express',
#   'brokerage'],
#  'Waste Management': ['say', 'share', 'tender', 'offer', 'dlrs'],
#  'USX &lt;X>': ['unit', 'prices', 'raises', 'crude', 'raise'],
#  'European\n  Community': ['say', 'EC', 'farm', 'export', 'plan'],
#  'Allegheny International Inc': ['say',
#   'Boston',
#   'dlrs',
#   'Railway',
#   'affiliate'],
#  'Shearson Lehman': ['say', 'Nippon', 'Life', 'investment', 'analyst'],
#  'U.S. Navy': ['platform', 'Gulf', 'oil', 'say', 'iranian'],
#  '>': ['pct', 'say', 'company', 'own', 'share'],
#  'Chemical Bank': ['say', 'pct', 'prime', 'rate', 'Trust'],
#  'MERGE': ['Republic', 'Savings', 'hold', 'NORSTAR', 'BANCORP'],
#  'Gencorp': ['say', 'General', 'dlrs', 'offer', 'company'],
#  'ASA': ['say', 'soybean', 'oil', 'Soybean', 'Association'],
#  'Trans World Airlines Inc': ['USAir', 'say', 'Group', 'share', 'buy'],
#  'Caesars World': ['say', 'Sosnoff', 'share', 'dlrs', 'offer'],
#  'Co>': ['say', 'unit', 'merge', 'tariff', 'month'],
#  'THAI': ['RISE', 'sugar', 'trade', 'deficit', 'widens'],
#  'The Finance Ministry': ['pct', 'bank', 'say', 'ask', 'dollar'],
#  'Reserve Bank': ['rand', 'rise', 'billion', 'mln', 'pct'],
#  'Standard': ['say', 'BP', 'dlrs', 'offer', 'pct'],
#  'LDP': ['say', 'plan', 'official', 'government', 'Liberal'],
#  'FNV': ['port', 'union', 'say', 'sector', 'transport'],
#  'Santa Fe': ['mm', 'Cordoba', 'say', 'Southern', 'Buenos'],
#  'Reuter': ['survey', 'mln', 'bpd', 'say', 'market'],
#  'WHITE HOUSE': ['say', 'japanese', 'TRADE', 'stand', 'firm'],
#  'Renault': ['Chrysler', 'say', 'dlrs', 'amc', 'mln'],
#  'Consolidated': ['billion', 'vs', 'franc', 'mln', 'net'],
#  'NASDAQ': ['say', 'trade', 'company', 'stock', 'list'],
#  'IMF': ['official', 'National', 'year', 'say', 'World'],
#  'Banco': ['Brasil', 'say', 'oil', 'billion', 'Foreign'],
#  'Smith Barney': ['say', 'analyst', 'stock', 'think', 'key'],
#  'Mobil': ['say', 'degree', 'oil', 'dlrs', 'price'],
#  'Texaco': ['say', 'Pennzoil', 'billion', 'company', 'crude'],
#  'Bangladesh': ['say', 'mln', 'billion', 'pct', 'October'],
#  'Phillips': ['Drew', 'say', 'Chris', 'Tinker', 'house'],
#  'PIK': ['corn', 'price', 'certificate', 'roll', 'cash'],
#  'U.S. Government': ['security', 'say', 'market', 'official', 'Federal'],
#  'Wagner': ['Brown', 'AFG', 'Inc', 'Industries', 'share'],
#  'Revlon': ['say', 'share', 'Gillette', 'dlrs', 'offer'],
#  'BUYS': ['STAKE', 'GANDER', 'wear', 'unit', 'WESTERN'],
#  'Commerce Department': ['say', 'official', 'yesterday', 'issue', 'show'],
#  'U.S. Trade': ['say', 'official', 'market', 'Japan', 'help'],
#  'First Boston': ['say', 'share', 'company', 'Allegheny', 'offer'],
#  'EC Commission': ['say', 'trade', 'source', 'European', 'Community'],
#  'KUWAIT': ['say', 'OPEC', 'see', 'WANTING', 'GULF'],
#  'State Department': ['say', 'official', 'reporter', 'United', 'Soviet'],
#  'Navy': ['say', 'platform', 'warship', 'second', 'iranian'],
#  'The Bank of France': ['market', 'rate', 'money', 'pct', 'intervention'],
#  'The Bank of Spain': ['money', 'pct', 'fund', 'bank', 'market'],
#  'DOT': ['say', 'application', 'TWA', 'file', 'Department'],
#  'Amstutz': ['say', 'certificate', 'subcommittee', 'loan', 'ask'],
#  'Purolator Courier Corp': ['say', 'share', 'offer', 'pct', 'Hutton'],
#  'central bank\n  ': ['say', 'pct', 'Bundesbank', 'tender', 'security'],
#  'FOB': ['dlrs', 'price', 'tonne', 'billion', 'say'],
#  'Bell': ['say', 'share', 'company', 'Inc', 'dlrs'],
#  'Inc>': ['say', 'acquire', 'company', 'Corp', 'pct'],
#  'Burlington': ['say', 'Dominion', 'lawyer', 'takeover', 'Edelman'],
#  'Bear Stearns': ['say', 'Co', 'analyst', 'sale', 'note'],
#  'Wilson': ['say', 'dlrs', 'question', 'billion', 'year'],
#  'Chrysler Corp': ['say', 'Motors', 'deal', 'dlrs', 'stock'],
#  'American Motors': ['say', 'Chrysler', 'Renault', 'stake', 'company'],
#  'First Boston Corp': ['say', 'dlrs', 'director', 'retain', 'price'],
#  'EIA': ['mln', 'say', 'pct', 'bpd', 'year'],
#  'Exxon Corp &lt;XON>': ['say', 'pct', 'joint', 'venture', 'unit'],
#  'U.S. Firms': ['say', 'buy', 'japanese', 'Japan', 'trade'],
#  'the National Bank': ['franc', 'billion', 'mln', 'Swiss', 'swiss'],
#  'Chicago Mercantile Exchange': ['floor',
#   'trader',
#   'commission',
#   'house',
#   'representative'],
#  'EXXON &lt;XON': [],
#  'Newmont Mining Corp': ['say', 'cent', 'copper', 'price', 'Magma'],
#  'the Federal Reserve Bank': ['New', 'York', 'say', 'billion', 'end'],
#  'the U.S. Dollar': ['currency', 'yen', 'say', 'japanese', 'european'],
#  'The Department': ['say', 'year', 'export', 'January', 'rise'],
#  'Caesars World Inc': ['share', 'Martin', 'Sosnoff', 'say', 'offer'],
#  'Caesars': ['Sosnoff', 'say', 'share', 'offer', 'shareholder'],
#  'the National Statistics Institute': ['pct', 'say', 'rise', 'price', 'INSEE'],
#  'BID': ['Corp', 'offer', 'Inc', 'say', 'share'],
#  'the General\n  Agreement on Tariffs and Trade': ['GATT',
#   'say',
#   'trade',
#   'talk',
#   'Japan'],
#  'DIXONS': ['CYCLOPS', 'say', 'pct', 'Group', 'offer'],
#  'Cabinet': ['say', 'trade', 'spokesman', 'al', 'Minister'],
#  'The Central Bank': ['issue', 'billion', 'cd', 'say', 'value'],
#  'District Court': ['say', 'file', 'suit', 'Inc', 'injunction'],
#  'American Express': ['say', 'Shearson', 'Nippon', 'mln', 'Life'],
#  'U.K. Interest': ['rate', 'say', 'market', 'sterling', 'month'],
#  'API': ['mln', 'say', 'barrel', 'week', 'pct'],
#  'Viacom': ['share', 'dlrs', 'offer', 'Redstone', 'Inc'],
#  'INDONESIA': ['palm', 'oil', 'import', 'CUTS', 'JULY'],
#  'Brazilian Coffee Institute': ['IBC', 'president', 'trader', 'say', 'Jorio'],
#  'LIFO': ['dlrs', 'vs', 'year', 'net', 'include'],
#  'CTS/BBL': ['canadian', 'WTI', 'posting', 'raise', 'LIGHT'],
#  'Union': ['say', 'dlrs', 'pct', 'offer', 'interest'],
#  'Reed': ['say', 'bid', 'company', 'Hughes', 'share'],
#  'Tehran Radio': ['say', 'quote', 'Iran', 'report', 'missile'],
#  'PDVSA': ['say', 'oil', 'company', 'Champlin', 'state'],
#  'Institute': ['say', 'need', 'pct', 'sugar', 'tree'],
#  'the Federal Reserve\n  Board': ['dlrs', 'say', 'bank', 'mln', 'billion'],
#  'TWA &lt;TWA': ['USAIR', 'refile', 'AGENCY', 'declines', 'COMMENT'],
#  'USAir\n  ': ['share', 'offer', 'Piedmont', 'buy', 'stock'],
#  'Hughes': ['say', 'Baker', 'merger', 'decree', 'consent'],
#  'the Federal Reserve Board': ['say', 'pct', 'bank', 'exchange', 'increase'],
#  'CTS\n  ': ['price', 'copper', 'cent', 'LOWERS', 'ASARCO'],
#  'the Central Bureau of Statistics': ['pct', 'say', 'rise', 'January', 'fall'],
#  'Southmark Corp': ['say', 'share', 'acquire', 'mln', 'dlrs'],
#  'Exchequer': ['Chancellor', 'say', 'rate', 'Nigel', 'Lawson'],
#  'UAL': ['stock', 'say', 'mln', 'share', 'dlrs'],
#  'IBM': ['say', 'dlrs', 'product', 'pct', 'company'],
#  'CANADA': ['say', 'trade', 'CONSUMER', 'PRICE', 'index'],
#  'NOTE - Company': ['billion', 'vs', 'current', 'net', 'sale'],
#  'Central': ['bank', 'governor', 'Chang', 'Chi', 'reserve'],
#  'QTR FEB 28': ['net'],
#  'the Labor\n  Department': ['week',
#   'say',
#   'unemployment',
#   'new',
#   'application'],
#  'HOG': ['cattle', 'slaughter', 'guesstimate'],
#  'The World Bank': ['say', 'loan', 'mln', 'development', 'country'],
#  'USX': ['say', 'oil', 'company', 'sale', 'pct'],
#  'Salomon Brothers Inc': ['say',
#   'analyst',
#   'share',
#   'purchase',
#   'shareholder'],
#  'sulphur': ['pct', 'dlrs', 'ct', 'say', 'price'],
#  'Commonwealth': ['say', 'KLM', 'stake', 'talk', 'door'],
#  "Borg-Warner's": ['dlrs', 'say', 'stock', 'pct', 'service'],
#  'ASCS': ['mln', 'pound', 'dlrs', 'say', 'price'],
#  'the Securities and\n  Exchange Commission': ['say',
#   'filing',
#   'share',
#   'dlrs',
#   'pct'],
#  'GAF &lt;GAF': ['BORG', 'WARNER', 'study', 'seeks', 'EXAMINING'],
#  'GAF Corp': ['Borg', 'Warner', 'say', 'Merrill', 'Lynch'],
#  'Amoco': ['say', 'billion', 'Dome', 'oil', 'available'],
#  "Chrysler Corp's": ['Motors', 'American', 'say', 'billion', 'proposal'],
#  'Ford': ['say', 'note', 'dlrs', 'General', 'Corp'],
#  'the Commerce\n  Department': ['say', 'billion', 'dlrs', 'pct', 'quarter'],
#  'Bank of England': ['rate', 'bank', 'follow', 'Robin', 'say'],
#  'Economic Policy Council': ['Reagan',
#   'Japan',
#   'administration',
#   'say',
#   'pact'],
#  'MLN STG': ['BIDS', 'assistance', 'NORCROS', 'DAIRY', 'FARM'],
#  'The Brazilian Coffee Institute': ['IBC',
#   'export',
#   'say',
#   'close',
#   'registration'],
#  'USX Corp': ['say', 'oil', 'year', 'chairman', 'David'],
#  'CHRYSLER': ['set', 'stock', 'split', 'raises', 'DIVIDEND'],
#  'International Coffee Organization': ['quota',
#   'coffee',
#   'say',
#   'ICO',
#   'export'],
#  'Jacobs': ['say', 'share', 'company', 'Borg', 'Warner'],
#  'the European Commission': ['say', 'EC', 'plan', 'sugar', 'intervention'],
#  'GULF': ['BARGE', 'FREIGHT', 'rate', 'reagan', 'IRANIAN'],
#  'SENATE': ['GULF', 'want', 'JAPAN', 'SEMICONDUCTER', 'pact'],
#  'Weinberger': ['say', 'Iran', 'platform', 'Gulf', 'attack'],
#  'QTR OPER': ['loss', 'CTS', 'SHR', 'VS', 'GREAT'],
#  'Department': ['say', 'tonne', 'official', 'import', 'USDA'],
#  'Lower House Budget Committee': ['tell',
#   'Parliament',
#   'Japan',
#   'nation',
#   'stabilize'],
#  'PSBR': ['stg', 'billion', 'say', 'Lawson', 'sector'],
#  'Taft Broadcasting Co': ['say', 'share', 'pct', 'dlrs', 'hold'],
#  'Co Ltd': ['say', 'market', 'price', 'mln', 'broker'],
#  'CBT': ['wheat', 'say', 'future', 'floor', 'contract'],
#  'CFTC': ['contract', 'say', 'Commodity', 'Futures', 'Trading'],
#  'Nippon': ['mln', 'say', 'investment', 'dlrs', 'share'],
#  'Visa': ['card', 'credit', 'say', 'west', 'german'],
#  'Lloyds': ['say', 'rate', 'London', 'attack', 'vessel'],
#  'GETS': ['say', 'offer', 'Corp', 'receive', 'Inc'],
#  'Nippon Life': ['American', 'Express', 'Shearson', 'say', 'Japan'],
#  'Colombo': ['say', 'Department', 'tonne', 'auction', 'supply'],
#  'the U.S. Position': ['say', 'Japan', 'boost', 'economic', 'shake'],
#  'BID\n  ': ['takeover', 'DART', 'group', 'drop', 'DAYTON'],
#  'SOUTHMARK &lt;SM>': ['acquires', 'OFFER', 'SPECIAL', 'DIVIDEND', 'ISSUE'],
#  'the International Monetary Fund\n  ': ['IMF',
#   'meeting',
#   'follow',
#   'government',
#   'manage'],
#  'the London Metal Exchange': ['LME', 'trader', 'New', 'stop', 'tin'],
#  'NATO': ['Greece', 'Turkey', 'avoid', 'force', 'say'],
#  'GE': ['dlrs', 'say', 'Heymann', 'quarter', 'business'],
#  'the House of Commons': ['tell', 'program', 'Wilson', 'question', 'say'],
#  'SPR': ['mln', 'crude', 'say', 'barrel', 'bpd'],
#  'mln stg bank': ['bill', 'band', 'pct', 'buy', 'treasury'],
#  'E.F. Hutton LBO Inc': ['Purolator', 'share', 'offer', 'Corp', 'say'],
#  'Lawson\n  ': ['say', 'rate', 'intervention', 'announce', 'week'],
#  "U.S. TREASURY'S": ['BAKER', 'says', 'currency', 'rate', 'SHIFTS'],
#  'The European Commission': ['tonne',
#   'say',
#   'intervention',
#   'authorise',
#   'export'],
#  'HOUSE': ['panel', 'want', 'PENTAGON', 'BILL', 'TRAFALGAR'],
#  'NORANDA': ['BEGINS', 'spin', 'forest', 'interests', 'SEPARATE'],
#  'Merrill Lynch Capital Markets': ['say',
#   'economist',
#   'Fed',
#   'policy',
#   'look'],
#  'Co Inc.': ['say', 'Fed', 'policy', 'time', 'economist'],
#  'bankers': ['say', 'pct', 'week', 'rise', 'ago'],
#  'TransCanada': ['Dome', 'say', 'offer', 'proposal', 'company'],
#  'ECU': ['billion', 'franc', 'currency', 'say', 'reserve'],
#  'Rubber Co': ['Tire', 'Goodyear', 'say', 'share', 'Corp'],
#  'Donaldson': ['say', 'Lufkin', 'Jenrette', 'Inc', 'Securities'],
#  'Chemical': ['mln', 'say', 'dlrs', 'net', 'income'],
#  'AFG Industries Inc': ['share', 'Wagner', 'Brown', 'tender', 'offer'],
#  'BORG-WARNER &lt;BOR': ['GAF', 'study', 'see', 'raise', 'seeks'],
#  'Dome Petroleum Ltd': ['Canada', 'Corp', 'say', 'billion', 'dlrs'],
#  'Reuters\n  ': ['tell', 'billion', 'Co', 'company', 'interview'],
#  'ITC': ['International', 'Tin', 'Council', 'say', 'anti'],
#  'Morgan Guaranty Trust Co': ['say', 'New', 'York', 'Inc', 'Corp'],
#  'Shell Oil Co': ['say', 'Royal', 'Dutch', 'Group', 'subsidiary'],
#  'Industrial Equity (Pacific) Ltd': ['pct',
#   'share',
#   'common',
#   'stock',
#   'firm'],
#  'Wireless Plc &lt;CAWL.L': ['Cable', 'merge', 'rival', 'say', 'hold'],
#  'Trade and Industry': ['Minister',
#   'Secretary',
#   'meeting',
#   'Hajime',
#   'Tamura'],
#  'the New York Times': ['say', 'include', 'missile', 'Gulf', 'Kuwait'],
#  'FHLBB': ['Savings', 'say', 'Home', 'Loan', 'Federal'],
#  'FCC': ['say', 'approval', 'att', 'Co', 'Inc'],
#  'FTC': ['say', 'order', 'approval', 'Cooper', 'acquisition'],
#  'Lloyds Shipping Intelligence': ['say', 'carrier', 'tonne', 'dw', 'motor'],
#  'ONIC': ['tonne', 'mln', 'say', 'french', 'Intervention'],
#  'the International Cocoa Organization': ['ICCO',
#   'buffer',
#   'stock',
#   'council',
#   'Kanon'],
#  'the European Monetary System': ['EMS', 'mark', 'say', 'join', 'currency'],
#  'U.S. EXPORT INSPECTIONS': ['THOUS', 'BUSHELS', 'corn', 'wheat', 'soybean'],
#  'Allied-Signal Inc': ['say', 'unit', 'complete', 'sale', 'dlrs'],
#  'Securities and\n  Exchange Commission': ['group',
#   'investor',
#   'tell',
#   'pct',
#   'acquire'],
#  'the National Statistics Office': ['pct',
#   'February',
#   'say',
#   'unemployment',
#   'end'],
#  'The International Cocoa Organization': ['buffer',
#   'stock',
#   'ICCO',
#   'say',
#   'rule'],
#  'ARCO': ['say', 'oil', 'dlrs', 'barrel', 'company'],
#  'the\n  department': ['mln', 'say', 'pct', 'unit', 'dlrs'],
#  'United Nations': ['conference', 'new', 'say', 'pact', 'negotiator'],
#  'Mutual Shares Corp': ['say', 'Inc', 'group', 'dlrs', 'buy'],
#  'Salomon': ['say', 'share', 'company', 'di', 'Clemente'],
#  'WEEK': ['BANK', 'dlrs', 'CANADA', 'say', 'MLN'],
#  'ICC': ['merger', 'say', 'company', 'Pacific', 'reopen'],
#  'NORWAY': ['pct', 'rise', 'deficit', 'FEBRUARY', 'TRADE'],
#  'Guinness': ['say', 'Ward', 'company', 'mln', 'Jersey'],
#  'Woolworth': ['mln', 'share', 'say', 'store', 'pct'],
#  'BP &lt;BP': ['BUY', 'STAKE'],
#  'the U.S. Embassy': ['say', 'report', 'Indonesia', 'reply', 'chinese'],
#  'Alcan': ['say', 'aluminum', 'car', 'structure', 'Bertone'],
#  'the International Coffee\n  Organization': ['ICO',
#   'coffee',
#   'quota',
#   'export',
#   'meeting'],
#  'Harper and Row': ['share', 'say', 'Cross', 'offer', 'pct'],
#  'The European Community Commission': ['say',
#   'export',
#   'tonne',
#   'trade',
#   'source'],
#  'Kidder Peabody': ['dlrs', 'Co', 'mln', 'analyst', 'Inc'],
#  'American Motors Corp': ['Chrysler', 'say', 'propose', 'mln', 'dlrs'],
#  'Keidanren': ['Japan', 'business', 'Eishiro', 'Saito', 'group'],
#  'the\n  International Tin Council': ['say',
#   'ITC',
#   'Agreement',
#   'delegate',
#   'buffer'],
#  'Co\n  ': ['say', 'buyer', 'Goldman', 'Sachs', 'Viner'],
#  "the Federal Reserve's": ['say', 'policy', 'pct', 'monetary', 'bill'],
#  'Bankers Trust': ['say', 'bank', 'interest', 'payment', 'assume'],
#  'Ecu': ['currency', 'coin', 'price', 'short', 'say'],
#  'Sun': ['price', 'say', 'gallon', 'bring', 'cent'],
#  'Buenos Aires': ['mm', 'Cordoba', 'tonne', 'rise', 'province'],
#  'Dow': ['say', 'dlrs', 'mln', 'price', 'chemical'],
#  'Morgan': ['mln', 'loss', 'say', 'dlrs', 'loan'],
#  'the U.S. Treasury': ['rate', 'dollar', 'interest', 'pct', 'reflect'],
#  'UAL Inc': ['say', 'stock', 'mln', 'tell', 'complete'],
#  'World Production and Trade Report': ['say',
#   'department',
#   'corn',
#   'season',
#   'mln'],
#  'the Senate Banking Committee': ['Volcker', 'say', 'testimony', 'tell', 'go'],
#  'The Agriculture Ministry': ['tonne', 'mln', 'Japan', 'estimate', 'say'],
#  'Credit Suisse': ['gold', 'warrant', 'swiss', 'franc', 'market'],
#  'Association': ['say', 'believe', 'tell', 'trade', 'day'],
#  'WORLD BANK': ['chief', 'urge', 'japanese', 'investment', 'IMF'],
#  'Gross National Product': ['pct', 'say', 'year', 'compare', 'Japan'],
#  'Merrill': ['Borg', 'Warner', 'say', 'share', 'cash'],
#  'MLN DLR': ['AUSTRALIA', 'MOBIL', 'report', 'loss', 'wholly'],
#  'the\n  International Monetary Fund': ['meeting',
#   'central',
#   'say',
#   'bank',
#   'monetary'],
#  'Southmark': ['say', 'right', 'share', 'dlrs', 'mln'],
#  'Drexel': ['say', 'Edelman', 'good', 'bond', 'Burnham'],
#  'BIL': ['say', 'Rainbow', 'share', 'progressive', 'bid'],
#  "the European Community's": ['mln', 'tonne', 'month', 'expect', 'legal'],
#  'SOVIET UNION': ['GRAIN', 'import', 'oilmeal', 'demand', 'STRONG'],
#  'the U.S. Agriculture Department\n  ': ['sale',
#   'say',
#   'Commodity',
#   'Credit',
#   'Corporation'],
#  'Westinghouse': ['mln', 'dlrs', 'Danforth', 'say', 'company'],
#  'the Commodity Exchange': ['New', 'York', 'gold', 'silver', 'gain'],
#  'Columbia': ['say', 'Federal', 'dlrs', 'share', 'talk'],
#  'Balao': ['pipeline', 'Ecuador', 'month', 'repair', 'export'],
#  'the Commerce Ministry': ['week', 'say', 'Thailand', 'tonne', 'end'],
#  'MTI': ['pct', 'say', 'today', 'rise', 'price'],
#  'Texaco Inc &lt;TX>': ['say', 'Corp', 'Shell', 'Pipeline', 'own'],
#  'Texaco Inc': ['say', 'oil', 'crude', 'company', 'operate'],
#  'Co Inc\n  ': ['report', 'George', 'Gordon', 'Paton', 'Peter'],
#  'BANGLADESH': ['ton', 'diesel', 'Bangladesh', 'trade', 'cost'],
#  'British Petroleum Co Plc &lt;BP.L': ['pct', 'Ltd', 'own', 'say', 'company'],
#  'Istat': ['say', 'pct', 'January', 'year', 'month'],
#  'International Monetary Fund': ['week',
#   'tell',
#   'rate',
#   'economic',
#   'introduce'],
#  'Senate Finance Committee': ['Lloyd', 'Bentsen', 'trade', 'D', 'Japan'],
#  'OFFER\n  ': ['REJECTS', 'PEPSICO', 'ACQUISITION'],
#  'MERGE\n  ': ['INDEPENDENCE', 'VANDERBILT', 'RAISE', 'COMMON', 'agree'],
#  'the Swiss National Bank': ['billion', 'say', 'franc', 'day', 'fall'],
#  'Investment': ['mln', 'vs', 'loss', 'income', 'long'],
#  'CCC ACCEPTS BONUS': ['BID', 'BARLEY', 'EGYPT', 'CATTLE', 'CANARY'],
#  'PaineWebber': ['say', 'company', 'Burlington', 'lawyer', 'Geodyne'],
#  'the Commerce Department\n  ': ['pct',
#   'report',
#   'February',
#   'monthly',
#   'figure'],
#  'the American Stock Exchange': ['stock', 'say', 'common', 'April', 'record'],
#  'DOE': ['oil', 'say', 'price', 'crude', 'dlrs'],
#  'Newmont': ['dlrs', 'say', 'mln', 'pct', 'Magma'],
#  'Amoco Corp &lt;AN>': ['Dome', 'executive', 'Calgary', 'base', 'independent'],
#  'Industrial Equity': ['say', 'own', 'dlrs', 'principally', 'Brierley'],
#  'Bermuda': ['base', 'firm', 'Fidelity', 'International', 'Ltd'],
#  'IDC': ['share', 'pct', 'Inc', 'hold', 'Ltd'],
#  'the American Soybean Association': ['say',
#   'ASA',
#   'soybean',
#   'tell',
#   'change'],
#  'the Federal Communications Commission': ['file',
#   'say',
#   'license',
#   'acquisition',
#   'right'],
#  'Standard Oil': ['tender', 'dlrs', 'say', 'BP', 'billion'],
#  'gm': ['octane', 'cent', 'lead', 'kerosene', 'litre'],
#  'Boeing': ['share', 'say', 'dlrs', 'option', 'pct'],
#  'ICCO': ['cocoa', 'buffer', 'stock', 'say', 'pound'],
#  'Finance\n  Ministry': ['say', 'Bank', 'official', 'week', 'pct'],
#  'ATPC': ['export', 'member', 'quota', 'say', 'tin'],
#  'the Commodity Credit Corporation': ['CCC',
#   'say',
#   'commodity',
#   'export',
#   'interest'],
#  'IEA': ['say', 'oil', 'mln', 'bpd', 'year'],
#  'First Boston Inc': ['share', 'say', 'dlrs', 'dlr', 'Allegheny'],
#  'Interim': ['vs', 'mln', 'dividend', 'billion', 'cent'],
#  'the Paris Club': ['debt', 'say', 'year', 'Nogales', 'rescheduling'],
#  'Becor Western Inc': ['say', 'dlrs', 'share', 'meeting', 'Corp'],
#  'Becor': ['say', 'dlrs', 'offer', 'Lynch', 'share'],
#  'Bank of Korea': ['figure', 'mln', 'provisional', 'February', 'dlrs'],
#  'CGCT': ['french', 'pct', 'telephone', 'mln', 'franc'],
#  'Pioneer': ['share', 'say', 'CSR', 'shareholder', 'pct'],
#  'Gillette': ['Revlon', 'share', 'say', 'board', 'dlrs'],
#  'House Agriculture Committee': ['meeting', 'bill', 'Kika', 'la', 'Garza'],
#  'Labour': ['Minister', 'say', 'Almir', 'Pazzionotto', 'government'],
#  'MOBIL &lt;MOB': [],
#  'Mobil Corp': ['say', 'mln', 'spend', 'dlrs', 'foot'],
#  'Defence': ['Secretary', 'say', 'official', 'Plc', 'Caspar'],
#  'the Organisation for\n  Economic Cooperation and Development': ['OECD',
#   'say',
#   'growth',
#   'half',
#   'year'],
#  'Kodak': ['say', 'Eastman', 'Carolina', 'share', 'mln'],
#  'CIF': ['pct', 'billion', 'rise', 'dlrs', 'FOB'],
#  'Chevron': ['say', 'Oil', 'Ltd', 'dlrs', 'oil'],
#  'U.S.\n  ': ['Treasury', 'meeting', 'Finance', 'Minister', 'Gerhard'],
#  'Drexel Burnham Lambert Inc': ['say',
#   'financial',
#   'advisor',
#   'offer',
#   'Allied'],
#  'the International Coffee Organisation': ['quota',
#   'ICO',
#   'say',
#   'export',
#   'main'],
#  'Schlumberger': ['say', 'Fujitsu', 'agreement', 'announce', 'sale'],
#  'Rostam': ['platform', 'Monday', 'Navy', 'mile', 'say']}

# %%
location_most_popular_terms
# Out:
# {'Europe': ['say', 'mln', 'export', 'Japan', 'market'],
#  'Gulf': ['say', 'oil', 'iranian', 'price', 'Iran'],
#  'Africa': ['say', 'East', 'Middle', 'year', 'country'],
#  'North America': ['say', 'pct', 'Europe', 'investment', 'local'],
#  'Asia': ['say', 'Europe', 'Oceania', 'South', 'billion'],
#  'the Middle East': ['say', 'oil', 'Africa', 'increase', 'fall'],
#  'the\n  Gulf': ['oil', 'say', 'soviet', 'Iran', 'tanker'],
#  'West': ['say', 'german', 'year', 'sale', 'commodity'],
#  'North Sea': ['oil', 'say', 'price', 'dlrs', 'cut'],
#  '1986/87': ['mln', 'tonne', 'forecast', 'export', 'vs'],
#  'Western Europe': ['mln', 'dlrs', 'say', 'billion', 'Japan'],
#  'Latin America': ['dlrs', 'pct', 'billion', 'say', 'mln'],
#  'Mediterranean': ['say', 'price', 'trader', 'country', 'Greece'],
#  'South America': ['say', 'production', 'import', 'soybean', 'likely'],
#  'the Far East': ['mln', 'say', 'pct', 'Europe', 'sale'],
#  'Middle East': ['oil', 'mln', 'official', 'supply', 'war'],
#  'Mideast': ['crude', 'oil', 'dlrs', 'OPEC', 'report'],
#  'Midwest': ['bank', 'corn', 'say', 'country', 'movement'],
#  'the Gulf of Mexico': ['say', 'pct', 'offshore', 'Louisiana', 'Texas'],
#  'New England': ['dlrs', 'banking', 'bank', 'say', 'year'],
#  'the Strait of Hormuz': ['say', 'Gulf', 'missile', 'Iran', 'shipping'],
#  'the North Sea': ['say', 'oil', 'field', 'company', 'Inc'],
#  'West Texas': ['say', 'Intermediate', 'price', 'company', 'post'],
#  'West Texas Sour': ['dlrs', 'barrel', 'price', 'Intermediate', 'bring'],
#  'Southeast Asia': ['say', 'Japan', 'decline', 'Africa', 'country'],
#  'Western\n  ': ['pct', 'country', 'say', 'year', 'oil'],
#  'Atlantic': ['say', 'side', 'Showboat', 'interest', 'subsidy'],
#  'the U.S. Gulf': ['dlrs', 'pay', 'pct', 'daily', 'long'],
#  'Pacific': ['pipeline', 'port', 'oil', 'Ecuador', 'mile'],
#  'Far East': ['dlrs', 'say', 'oil', 'barrel', 'mln'],
#  'the Aegean Sea': ['turkish', 'dispute', 'say', 'research', 'water'],
#  'Southwest': ['say', 'area', 'ct', 'lb', 'propose'],
#  'Persian Gulf': ['say', 'oil', 'tanker', 'pct', 'free'],
#  'EUROPE': ['JAPAN', 'new', 'currency', 'problem', 'SEEN'],
#  'South': ['cotton', 'East', 'price', 'soybean', 'say'],
#  'East': ['West', 'Midwest', 'mln', 'bank', 'loss'],
#  'Northeast': ['say', 'share', 'result', 'strong', 'sale'],
#  'the Mideast Gulf': ['mln', 'say', 'ton', 'protect', 'source'],
#  'Prudhoe Bay': ['say', 'oil', 'field', 'area', 'discovery'],
#  'Caribbean': ['country', 'EC', 'ACP', 'say', 'Cano'],
#  'Gulf\n  ': ['say', 'missile', 'Iran', 'oil', 'iranian'],
#  'west coast': ['Africa', 'tonner', 'dlrs', 'USAir', 'Sudan'],
#  'Arabian Sea': ['Navy', 'aircraft', 'carrier', 'Kitty', 'northern'],
#  'Plaza': ['month', 'agreement', 'dollar', 'say', 'trade'],
#  'Eastern Europe': ['mln', 'forecast', 'say', 'planting', 'export'],
#  'the Northern Territory': ['gold', 'pct', 'new', 'stake', 'say'],
#  'NORTH SEA': ['sell', 'property', 'unit', 'WHITEHALL', 'cash'],
#  'the East Coast': ['say', 'Corp', 'italian', 'firm', 'Steuart'],
#  'the Arctic National Wildlife Refuge': ['oil',
#   'Hodel',
#   'urge',
#   'Congress',
#   'approve'],
#  'Scandinavia': ['share', 'group', 'firm', 'Baker', 'treatment'],
#  'the West Coast': ['say', 'sale', 'bank', 'new', 'New'],
#  'the Gulf\n  ': ['say', 'Iran', 'oil', 'attack', 'Aqazadeh'],
#  'West\n  ': ['Finance', 'country', 'german', 'say', 'contact'],
#  'the Black Sea': ['say', 'soviet', 'charterer', 'report', 'Aqazadeh'],
#  'the Pacific coast': ['km', 'oil', 'official', 'say', 'Ecuador'],
#  'Straits': ['Gulf', 'Hormuz', 'move', 'ship', 'Weinberger'],
#  'East Bloc': ['diplomat', 'say', 'expect', 'kind', 'social'],
#  'Louvre': ['say', 'current', 'range', 'broadly', 'consistent'],
#  'North Sea Brent': ['crude', 'dlrs', 'oil', 'price', 'unchanged'],
#  'Nova': ['Blair', 'net', 'profit', 'year', 'mln'],
#  'East Coast': ['say', 'bank', 'Exxon', 'expand', 'marketing'],
#  'Gulf Coast': ['well', 'Texas', 'Louisiana', 'Scripps', 'Corp'],
#  'Mideast Gulf': ['Reagan', 'President', 'House', 'require', 'administration'],
#  'the Persian Gulf': ['Congress', 'ship', 'Iran', 'administration', 'require'],
#  'Suez': ['tonne', 'CPC', 'say', 'government', 'Gulf'],
#  'the Neutral Zone': ['bpd', 'mln', 'production', 'barrel', 'Saudi'],
#  'Central': ['mln', 'failure', 'seasonal', 'rain', 'seriously'],
#  'the Cooper Basin': ['oil', 'Australia', 'pct', 'Santos', 'Ltd'],
#  'Southern California': ['Citicorp', 'branch', 'thrift', 'say', 'acquisition'],
#  'the Middle\n  East': ['outside', 'look', 'world', 'scrape', 'mln'],
#  'Eastern\n  Bloc': ['figure', 'exclude', 'exchange', 'pay', 'non'],
#  'Eastern Bloc': ['country', 'world', 'tonne', 'February', 'zinc'],
#  'West Coast': ['shipment', 'dlrs', 'large', 'passenger', 'carrier'],
#  'midwest': ['planting', 'increase', 'sugarbeet', 'farmer', 'say'],
#  'Delta': ['ruling', 'official', 'Western', 'Appeals', 'Court'],
#  'the Mississippi River': ['bank', 'elevator', 'say', 'loss', 'year'],
#  'the\n  gulf': ['tell', 'Iran', 'defense', 'official', 'Reuters'],
#  'South\n  Africa': ['say', 'close', 'emergence', 'competitor', 'follow'],
#  'the Far\n  East': ['iranian', 'oil', 'surface', 'Gulf', 'report'],
#  'Sao\n  Paulo': ['Mato', 'Grosso', 'rally', 'city', 'km'],
#  'the Pacific Ocean': ['pipeline', 'field', 'repair', 'Ecuador', 'oil'],
#  'Pearl River': ['China', 'Sea', 'quote', 'spokesman', 'National'],
#  'Greens Creek': ['Co', 'venture', 'Inc', 'unit', 'Hecla'],
#  'the Texas Gulf Coast': ['dlrs', 'Chairman', 'Gordon', 'Cain', 'previously'],
#  'North\n  America': ['mln', 'trip', 'attempt', 'meet', 'farm'],
#  'the West\n  ': ['agency', 'note', 'final', 'order', 'PSA'],
#  'San Joaquin Valley': ['Coast', 'say', 'acquisition', 'entry', 'market'],
#  'Pacific Coast': ['northern', 'Todd', 'Shipyards', 'Corp', 'say'],
#  'trans-Atlantic': ['tonner', 'dlrs', 'daily', 'secure', 'round'],
#  'South East Asia': ['mln', 'vs', 'Far', 'import', 'see'],
#  'Caicos Islands': ['VBI', 'Turks', 'investment', 'firm', 'Vik'],
#  'Arctic': ['government', 'Dome', 'company', 'say', 'icebreaker'],
#  'Jupiter': ['Corp', 'Kresge', 'store', 'privately', 'hold'],
#  'the Red River': ['pipeline', 'say', 'small', 'Total', 'closed'],
#  'South Florida': ['say', 'Financial', 'Security', 'Savings', 'Loan'],
#  'the Southern District': ['Viacom', 'Inc', 'say', 'New', 'York'],
#  'gulf': ['day', 'official', 'House', 'vote', 'today'],
#  'south central': ['storm', 'area', 'Alberta', 'lack', 'moisture'],
#  'the South Pacific': ['dlrs', 'deadweight', 'tonne', 'bulk', 'carrier'],
#  'South-east': ['Bank', 'call', 'overhaul', 'Indonesia', 'manage'],
#  'Southern Pacific': ['corporate', 'headquarters', 'lose', 'period', 'Crown'],
#  'Northern California': ['Citicorp',
#   'Savings',
#   'predominantly',
#   'Security',
#   'Pacific'],
#  'Western\n  Europe': ['Malaysia', 'say', 'low', 'Ng', 'Siew'],
#  'Kharg Island': ['Iran', 'oil', 'terminal', 'predict', 'United'],
#  'the Beaufort Sea': ['gas', 'SALE', 'POSTPONED', 'Outer', 'Continental'],
#  'The Great Atlantic': ['Pacific', 'Tea'],
#  'South Louisiana Sweet': ['dlrs', 'increase', 'barrel', 'dlr'],
#  'SOUTHERN GULF': ['AIRCRAFT', 'ATTACK', 'IRANIAN', 'oil', 'rigs'],
#  'South\n  ': ['black', 'miner', 'kill', 'injure', 'rock'],
#  'Ketza River': ['say', 'conditionally', 'approve', 'start', 'production'],
#  'Bass Strait\n  ': ['fall', 'pct', 'sale', 'BPD', 'BHP'],
#  'Cenepa': ['Garcia', 'say', 'gold', 'bearing', 'deposit'],
#  'Asia-Pacific': ['open', 'market', 'opportunity', 'option', 'have'],
#  'the southwest Pacific': ['City', 'Resources', 'Ltd', 'say', 'agree'],
#  'Valley': ['low', 'temperature', 'tonight', 'Texas', 'expect'],
#  'the Lower Valley': ['cotton', 'planting', 'progress'],
#  'West Europe': ['trade', 'EC', 'general', 'country', 'Japan'],
#  'Bass Strait': ['oil', 'say', 'onshore', 'find', 'excise'],
#  'Lake Erie': ['Ontario', 'say', 'freight', 'year', 'mln'],
#  'Kansai': ['international', 'airport', 'firm', 'construction', 'Matsunaga'],
#  'the North China Plain': ['wheat', 'cover', 'winter', 'say', 'area'],
#  'Echo Bay\n  ': ['McCoy', 'gold', 'discovery', 'property', 'mile'],
#  'Western': ['Delta', 'airline', 'argue', 'promise', 'enforce'],
#  'the\n  Illinois': ['corn', 'soybean', 'basis', 'value', 'continue'],
#  'MidMississippi River': ['corn', 'soybean', 'basis', 'value', 'continue'],
#  'earth': ['say', 'ozone', 'layer', 'harvest', 'area'],
#  'the Red Sea': ['dlrs', 'barley', 'cargo', 'arrange', 'Immingham'],
#  'Western Australia': ['company', 'agree', 'sell', 'oil', 'gas'],
#  'Amazon': ['oil', 'brazilian', 'state', 'company', 'petrobra'],
#  'Yangtze': ['say', 'paper', 'rainfall', 'day', 'March'],
#  'the Gulf war zone': ['Kuwait', 'register', 'tanker', 'fleet', 'foreign'],
#  'Americas': ['business', 'Wormald', 'group', 'begin', 'exploratory'],
#  'the Uruguay Round': ['urge', 'great', 'involvement', 'trade', 'minister'],
#  'the\n  Mark': ['Bank', 'set', 'Lira', 'rate', 'previous'],
#  'Central America': ['State', 'department', 'major', 'player', 'set'],
#  'east coast': ['USAir', 'mln', 'cubic', 'foot', 'natural'],
#  'North Yemen': ['Commodity', 'Credit', 'Corporation', 'CCC', 'accept'],
#  'the Southern Pacific': ['Santa', 'Fe', 'say', 'Kansas', 'City'],
#  'the Illinois River': ['pct', 'offer', 'week', 'south', 'Chicago'],
#  'Trump': ['Resorts', 'Atlantic', 'City', 'say', 'statement'],
#  'S': ['mln', 'minority', 'interest', 'vs', 'extraordinary'],
#  'west': ['Joe', 'Gold', 'say', 'Golden', 'Patricia'],
#  'Muskeg Lake': ['property', 'exploration', 'continue', 'Golden', 'Patricia'],
#  'the\n  Pacific': ['President', 'say', 'enable', 'boost', 'service'],
#  'Yellow Sea': ['China', 'quote', 'spokesman', 'National', 'Offshore'],
#  'MIDEAST': ['AUSTRALIA', 'EXPECTS', 'RISE', 'meat', 'exports'],
#  'The Middle East': ['Gulf', 'particular', 'Australia', 'large', 'market'],
#  'Wood Mackenzie': ['stockbroker', 'Co', 'profit', 'Philip', 'Augar'],
#  'Lake Victoria': ['railway', 'kenyan', 'delay', 'Uganda', 'export'],
#  'the Pacific Coast': ['pipeline', 'Cruz', 'construction', 'Salina', 'link'],
#  'Oak Harbour': ['Home', 'Loan', 'Bank', 'Savings', 'Washington'],
#  'the\n  Neutral Zone': ['current', 'production', 'mln', 'bpd', 'include'],
#  'Central\n  America': ['country',
#   'Washington',
#   'account',
#   'ally',
#   'instance'],
#  'the middle east': ['lie', 'government', 'study', 'conclude', 'dependent'],
#  'Pivot': ['fire', 'source', 'casualty', 'see', 'tanker'],
#  'the\n  bloc': ['EC', 'rebate', 'grant', 'yesterday', 'sugar'],
#  'South Asia': ['Tropical', 'Africa', 'Middle', 'East', 'turn'],
#  'Suharto': ['Tuesday', 'day', 'detailed', 'discussion', 'minister'],
#  'North Island': ['meeting', 'tourist', 'resort', 'describe', 'participant'],
#  'the Gulf area': ['say', 'ship', 'Weinberger', 'Iran', 'iranian'],
#  'Admiralty Island': ['zinc', 'gold', 'silver', 'ore', 'short'],
#  'the Adelaide River': ['locate', 'kms', 'east', 'Bundey', 'WMC'],
#  'Industrial Valley': ['asset', 'mln', 'dlrs', 'acquire', 'year'],
#  'the Aegean\n  Sea': ['Turkey', 'say', 'today', 'dispute', 'Greece'],
#  'Colville Delta\n  ': ['United', 'States', 'Union', 'Texas', 'say'],
#  'Eugene Island Block': ['Union', 'Texas', 'say', 'plan', 'spend'],
#  'Highland Valley': ['Cominco', 'pct', 'copper', 'venture', 'Lornex'],
#  'Old Crow': ['analyst', 'say', 'National', 'Distillers', 'spirit'],
#  'the\n  West': ['western', 'analyst', 'attribute', 'deficit', 'rise'],
#  'WEST COAST': ['TODD', 'SHIPYARDS', 'strike'],
#  'Continent': ['business', 'involve', 'significant', 'voyage', 'Japan'],
#  'Far\n  East': ['currency', 'market', 'initial', 'reaction', 'demonstrate'],
#  'Northern Hemisphere': ['buoyancy',
#   'generally',
#   'attribute',
#   'trader',
#   'low'],
#  'Waccamaw\n  ': ['Anchor', 'share', 'Financial', 'Corp', 'say'],
#  'East Europe': [],
#  'east central': ['Corp', 'Centel', 'say', 'complete', 'acquisition'],
#  'the Central District': ['subject', 'company', 'say', 'purchase', 'price'],
#  'South East': ['X', 'Ind', 'Ky', 'Ohio'],
#  'South Central': [],
#  'South West': [],
#  'Northern Europe': ['crude', 'oil', 'price', 'netback', 'value'],
#  'Parana River': ['increase', 'maize', 'tonne', 'Buenos', 'Aires'],
#  'Pacific ocean': ['link', 'Lago', 'Agrio', 'pipeline', 'port'],
#  'Sime Darby': ['November', 'KIO', 'aggressively', 'open', 'market'],
#  'Papuan\n  Basin': ['Merlin', 'pct', 'stake', 'adjacent', 'permit'],
#  'the Gulf of Thailand': ['Oil', 'field', 'southern', 'sector', 'currently'],
#  'North America 334': ['mln', 'vs', 'Europe', 'Central', 'South'],
#  'Central and South America 21': ['mln', 'vs', 'Europe', 'North'],
#  'Dome': ['share', 'TransCanada', 'Canada', 'large', 'natural'],
#  "South Atlantic's": ['share', 'independence', 'SAFCO', 'own', 'pct'],
#  'Both South Atlantic': ['Independence', 'insurance', 'company'],
#  'Duluth': ['official', 'say', 'hard', 'red', 'spring'],
#  'Midlantic': ['share', 'County', 'say', 'pay', 'dlrs'],
#  'Paris Basin': ['mln', 'barrel', 'Triton', 'Energy', 'Corp'],
#  'Sierras': ['sale', 'line', 'mainframe', 'commonly', 'call'],
#  'Eastern Massachusetts': ['office',
#   'Accountemps',
#   'franchise',
#   'New',
#   'England'],
#  'the Texas\n  ': ['well', 'Gulf', 'Louisiana', 'agreement', 'call'],
#  'the Gulf of Suez': ['Canada', 'Corp', 'say', 'acquire', 'pct'],
#  'East\n  ': ['Hurghada', 'company', 'say', 'agreement', 'operator'],
#  'the Lago\n  Agrio': ['schedule', 'date', 'inauguration', 'Puerto', 'Colon'],
#  'Bulolo Valley': ['metre', 'City', 'Resources', 'say', 'previous'],
#  '6.5/6.6 tonnes': ['yield', 'French', 'Feed', 'Cereals', 'Research'],
#  'Rohm': ['say', 'sale', 'Polyco', 'Cincinnati', 'Ohio'],
#  'Snyder': ['Geodyne', 'senior', 'management', 'member', 'serve'],
#  'Heidrun': ['Conoco', 'Statoil', 'oil', 'field', 'government'],
#  'East Coast Sales': ['Semicon', 'Tools', 'Inc', 'say', 'sign'],
#  'the MIDEAST Gulf': ['say', 'ally', 'dependence', 'gulf', 'oil'],
#  'Okla': ['Texas', 'flood', 'Red', 'River', 'Oklahoma'],
#  'the Red River\n  ': ['pipeline', 'Stevens', 'say', 'day', 'flood'],
#  'Lake Texoma': ['Texaco', 'Stevens', 'say', 'aerial', 'surveillance'],
#  'Trigon': ['price', 'DOE', 'allege', 'cause', 'overcharge'],
#  'the South Australian\n  Cooper Basin': ['acquisition',
#   'late',
#   'series',
#   'Santos',
#   'program'],
#  'the Jaffna peninsula': ['Sri', 'Lanka', 'today', 'order', 'armed'],
#  'Pacific\n  ': ['ACP', 'ambassador', 'EC', 'african', 'Caribbean'],
#  'Johnny\n  Mountain Camp': ['say',
#   'expect',
#   'construction',
#   'begin',
#   'month'],
#  'the Mideast\n  Gulf': ['military', 'force', 'order', 'protect', 'american'],
#  'the western gulf': ['protect', 'shipping', 'ship', 'Bahrain', 'Caspar'],
#  'Telegraph': ['year', 'Daily', 'break', 'better', 'say'],
#  'the MidEast Gulf': ['say', 'force', 'Warner', 'leader', 'Senate'],
#  'the Gulf Arab states': ['force', 'Glenn', 'voice', 'preference', 'United'],
#  'barley\n  ': ['mln', 'year', 'oats', 'acreage', 'unchanged'],
#  'Soil': ['moisture', 'well', 'north', 'central', 'Peace'],
#  'the Japan Ship': ['gt', 'ship', 'new', 'foreign', 'shipbuilding'],
#  'the Middle and Far East': ['Africa'],
#  'Peninsula': ['Malaysia', 'shift', 'planting', 'Sabah', 'Sarawak'],
#  'the Eastern Hemisphere': ['Xerox', 'Rank', 'South', 'Africa', 'found'],
#  'The West Texas Sour': ['grade', 'api', 'stand', 'dlrs', 'barrel'],
#  'eastern seaboard': ['gas', 'Natural', 'Gas', 'Co', 'supply'],
#  'Red Sea': ['Iraq', 'National', 'Oil', 'Co', 'INOC'],
#  'the far east': ['Soviet', 'Union', 'lack', 'adequate', 'repair'],
#  'Dome\n  Mountain': ['Total', 'Erickson', 'say', 'purchase', 'Consolidated'],
#  'the Rhine river': ['dutch', 'salvage', 'firm', 'Smit', 'Tak'],
#  'Southern Africa': ['country', 'Eastern', 'agree', 'cut', 'tariff'],
#  'Parachute Creek': ['Unocal', 'Corp', 'say', 'tell', 'Treasury'],
#  'Koether': ['company', 'group', 'say', 'Paul', 'meet'],
#  'the Western Hemisphere': ['point',
#   'Dominican',
#   'Republic',
#   'mexican',
#   'nearby'],
#  'the Far East\n  ': ['market', 'action', 'past', 'week', 'raw'],
#  'COFFEE QUOTAS UNCERTAIN': ['colombia', 'helpful'],
#  'cif Mideast Gulf': ['propane', 'dlrs', 'appear', 'ease', 'slightly'],
#  'Gidgealpa South': ['production', 'say', 'proximity', 'discovery', 'exist'],
#  'Mideast Dubai': ['dlrs', 'trader', 'say', 'early', 'Tokyo'],
#  'the Western Corn Belt\n  ': ['bring', 'weekend', 'rain', 'relief', 'crop'],
#  'the central Midwest': ['Mohler', 'say', 'cold', 'eastern', 'belt'],
#  'the Corn Belt': ['early', 'bring', 'new', 'rain', 'pattern'],
#  'Greenery': ['year', 'building', 'lease', 'initial', 'term'],
#  "the Bay Area's": ['addition', 'say', 'loss', 'corporate', 'leadership'],
#  'the Sea Isle\n  City': ['Washington',
#   'say',
#   'attack',
#   'response',
#   'missile'],
#  'the Hormuz Strait': ['say', 'Iran', 'IRNA', 'give', 'explicit'],
#  'the Artic Ocean\n  ': ['area', 'mile', 'northern', 'coast', 'Alaska'],
#  'The West Texas': ['Sour', 'Light', 'Louisiana', 'Sweet', 'grade'],
#  'Gulf sea': ['captain', 'report', 'steer', 'clear', 'Iran'],
#  'Southern Texas': ['say', 'plant', 'grow', 'reach', 'height'],
#  'Gold River': ['newsprint', 'CIP', 'Canada', 'second', 'large'],
#  'Atlantic\n  ': ['dwindle', 'global', 'crude', 'oil', 'reserve'],
#  'West Texas Sour\n  ': ['bring', 'price', 'company', 'pay', 'benchmark'],
#  'the Sea Isle City': ['Iran', 'deter', 'accord', 'defense', 'official'],
#  'the Middle East\n  ': ['Henry', 'Schuler', 'diplomat', 'CSIS', 'say'],
#  'the Gulf Arab\n  ': ['escalation', 'war', 'threaten', 'state', 'work'],
#  'Sea\n  Isle City': ['Weinberger', 'say', 'platform', 'military', 'base'],
#  'Southern Pafific Transportation': ['Fe', 'dlrs', 'company', 'say', 'review'],
#  'the Sea\n  Isle City': ['Attack', 'retaliation', 'Friday', 'hit', 'Kuwaiti'],
#  'the Faw Peninsula': ['initial', 'upward', 'market', 'morning', 'reflect'],
#  'the Gulf east': ['broadcast', 'monitor', 'Nicosia', 'say', 'civilian'],
#  'Guernsey': ['BCI', 'say', 'new', 'fund', 'structure'],
#  'Mount Snow': ['ski', 'K', 'own', 'Killlington', 'resort'],
#  'San\n  ': ['ski', 'K', 'own', 'Killlington', 'Mount'],
#  'Central Soya\n  ': ['term', 'mln', 'dlrs', 'sale', 'agreement'],
#  'Triton': ['company', 'say', 'inform', 'present', 'good'],
#  'Illinois Central Gulf': ['IC', 'board', 'earlier', 'approve', 'plan'],
#  'Lavan island': ['oil', 'IRNA', 'receive', 'Nicosia', 'say'],
#  'the Mideast Gulf\n  ': ['LPG', 'fear', 'supply', 'say', 'trader'],
#  'South Yemen': ['MEES', 'pipeline', 'export', 'initial', 'bpd'],
#  "North Yemen's": ['discovery', 'commercial', 'quaotitie', 'oil', 'confirm'],
#  'North Sea Veslefrikk': ['field', 'operator', 'Norway', 'oil', 'place'],
#  'the Gulf\n  war': ['Iran', 'lose', 'refining', 'capacity', 'early'],
#  'Caspian Sea': ['Aqazadeh', 'say', 'soviet', 'refined', 'product'],
#  'the Gulf': ['conference', 'spokesman', 'decline', 'take', 'time'],
#  'South\n  East Asia': ['report', 'iron', 'import', 'EXPECTS', 'sharp'],
#  '4th qtr': ['vs', 'loss', 'year', 'extraordinary', 'ago'],
#  'the Campos Basin': ['drop', 'operating', 'problem', 'country', 'main'],
#  'KETZA RIVER\n  ': ['gold', 'PRODUCTION', 'START'],
#  'Smoky River Coal': ['McIntyre', 'say', 'mln', 'dlrs', 'retain'],
#  'Smoky\n  ': ['McIntyre', 'say', 'provide', 'mln', 'dlr'],
#  'valley': ['real', 'question', 'broad', 'year'],
#  'the Pacific Northwest': ['Department', 'tonne', 'Sri', 'Lankan', 'Food'],
#  'New South Wales': ['group', 'Ltd', 'northern', 'regional', 'emerge'],
#  "Northern Star's": ['mln', 'dlrs', 'issue', 'placement', 'share'],
#  'tonnes': ['Feb', 'sale', 'end', 'month', 'stock'],
#  'FOB Gulf': ['dlrs', 'tonne', 'June', 'wheat', 'SRW'],
#  'FOB\n  Gulf': ['yellow', 'corn', 'pct', 'maximum', 'moisture'],
#  'the Evros River': ['greek', 'newspaper', 'report', 'army', 'navy'],
#  'Thasos island': ['international', 'Greek', 'base', 'consortium', 'North'],
#  'BfG': ['mark', 'AMB', 'say', 'mln', 'drop'],
#  'Queensland': ['australian', 'dry', 'area', 'sugar', 'cane'],
#  'Mackay\n  ': ['industry', 'worried', 'week', 'ago', 'rainfall'],
#  'Skanska': ['say', 'appoint', 'board', 'member', 'canadian'],
#  'Thassos': ['Aegean', 'oil', 'island', 'row', 'erupt'],
#  'Bow Valley': ['company', 'say', 'Bowcan', 'Holdings', 'Inc'],
#  'Norwest Gypsum': ['Louisiana', 'Pacific', 'Corp', 'say', 'reach'],
#  'the Mediterranean \n  ': ['netback', 'value', 'ct', 'crude', 'oil'],
#  'the mediterranean region': ['netback', 'value', 'show', 'dlrs', 'barrel'],
#  'Netbacks': ['Northern', 'Europe', 'refinery', 'region', 'low'],
#  "Northern Europe's": ['low', 'friday', 'previous', 'Brent', 'dlrs'],
#  'Northern\n  Europe': ['netback', 'grade', 'oil', 'refine', 'show'],
#  'Central Governmnet': ['add', 'Dauster', 'keen', 'raise', 'contribution'],
#  'South Texas': ['begin', 'area', 'Stillmann', 'cotton', 'market'],
#  'Pine Bluff': ['file', 'proposal', 'Arkansas', 'Public', 'Service'],
#  'the North-West Shelf': ['largely', 'related', 'Ltd', 'unit', 'non'],
#  'Danes': ['hold', 'whichever', 'country', 'group', 'monthly'],
#  'the Bass Strait': ['purchase', 'give', 'Esso', 'partner', 'Broken'],
#  'Bass\n  Strait': ['discovery', 'help', 'Australia', 'self', 'sufficiency'],
#  'Middle\n  ': ['decline', 'transatlantic', 'traffic', 'follow', 'terrorist'],
#  'the\n  Atlantic': ['year', 'airline', 'force', 'axe', 'job'],
#  'these North Sea': ['crude', 'light', 'sweet', 'produce', 'field'],
#  'Republic': ['company', 'stock', 'Pioneer', 'association', 'say'],
#  'Lake Ontario': ['freight', 'year', 'mln', 'tonne', 'seaway'],
#  'Lake\n  Ontario': ['freight', 'year', 'mln', 'tonne', 'seaway'],
#  'New Harding': ['earlier', 'report', 'profit', 'dlrs', 'ct'],
#  'the Gulf of\n  Mexico': ['shelf',
#   'lease',
#   'offshore',
#   'Southern',
#   'California'],
#  'the Upper Coast': ['Coastal', 'Bend', 'Texas'],
#  'the Gulf or Great Lakes': ['shipment'],
#  'Southeast\n  ': ['Taiwan', 'tonne', 'steel', 'export', 'Japan'],
#  'Picardy': ['planting', 'say', 'estimate', 'intention', 'indicate'],
#  'the Paris Basin': ['planting', 'say', 'estimate', 'intention', 'indicate'],
#  'the south-east': ['pct', 'plant', 'intention', 'range', 'year'],
#  'Georgia Gulf': ['mln', 'share', 'company', 'say', 'sell'],
#  'Buenos Aires\n  ': ['weather', 'bureau', 'say', 'rain', 'surpass'],
#  'MidMississippi River\n  ': ['week', 'pct', 'bid', 'June', 'offer'],
#  'Illinois River': ['December', 'ex', 'Chicago'],
#  'west\n  ': ['Mobil', 'Corp', 'say', 'raise', 'coast'],
#  'Kern River': ['crude', 'degree', 'increase', 'dlr', 'dlrs'],
#  'Illinois Central Gulf Railroad': ['subsidiary',
#   'IC',
#   'Industries',
#   'Inc',
#   'say'],
#  'the Eastern Coast': ['New', 'Zealand', 'wheat', 'Australia', 'report'],
#  "d'America e d'Italia": ['SpA', 'pct', 'acquire', 'Bankamerica', 'Corp'],
#  'the Gulf Coast': ['environmental',
#   'service',
#   'International',
#   'Technology',
#   'hazardous'],
#  'Silver': ['tonne', 'troy', 'ounce'],
#  'Northern\n  ': ['company', 'California', 'say', 'settlement', 'relate'],
#  'Mile Island': ['dividend', 'General', 'Public', 'Utilities', 'Corp'],
#  'Texas Gulf': ['structure', 'relate', 'Louisiana'],
#  'the Louisiana Gulf': ['rumor', 'circulate', 'market', 'morning', 'USDA'],
#  'Far East\n  ': ['export', 'pct', 'Western', 'Europe', 'ease'],
#  'Baltic Sea': ['tonner', 'voyage', 'fixture', 'report', 'soviet'],
#  'the Continent\n  ': ['dlrs', 'grain', 'fixing', 'Gulf', 'quieter'],
#  'the Gulf to Jamaica': ['grain', 'fixing', 'quieter', 'fresh', 'business'],
#  'Cherry\n  Valley': ['Park', 'cable', 'system', 'serve', 'subscriber'],
#  'the\n  Rankin Inlet': ['gold',
#   'prospect',
#   'acre',
#   'Northwest',
#   'Territories'],
#  'North sea': ['dlrs', 'trade', 'oil', 'market', 'Dubai'],
#  'Cravo Norte': ['Petroleum', 'Shell', 'spokeswoman', 'company', 'say'],
#  'The\n  Tentonian': ['Publishers', 'Equipment', 'Corp', 'say', 'reach'],
#  'the Indian Ocean': ['newspaper', 'quote', 'Pentagon', 'official', 'say'],
#  'the Strait of\n  Hormuz': ['say',
#   'paper',
#   'month',
#   'Intelligence',
#   'source'],
#  'the Central Asian\n  republic of Kazakhstan': ['situation',
#   'particularly',
#   'bad',
#   'severely',
#   'criticise'],
#  'Central Bak': ['Egypt', 'leave', 'dollar', 'rate', 'commercial'],
#  'Black Warrior Basin': ['company', 'say', 'suit', 'file', 'seekiong'],
#  'mid-Atlantic': ['company', 'say', 'pct', 'Millen', 'card'],
#  'Canadian Tire': ['CTC', 'Ontario', 'group', 'dealer', 'own'],
#  'the Dallas Metroplex': ['practice',
#   'metropolitan',
#   'area',
#   'dental',
#   'office'],
#  'the Black\n  Sea coast': ['winter', 'grain', 'remain', 'dormant', 'region'],
#  'Keg River': ['well', 'flow', 'oil', 'formation', 'constrain'],
#  'the Texas Gulf': ['interior', 'grain', 'soybean', 'price', 'affected'],
#  'Amoskeag': ['ramification',
#   'decision',
#   'believe',
#   'affiliation',
#   'Portsmouth'],
#  'Allegheny': ['suit', 'request', 'injunction', 'proceed', 'pende'],
#  '2nd qtr': ['dlrs', 'net', 'include', 'gain', 'month'],
#  'Algiers': ['Youcef', 'Yousfi', 'director', 'general', 'Sonatrach'],
#  'ASIA': ['pressure', 'urge', 'BEEF'],
#  "FEB\n  South Africa's": ['SHARPLY', 'total', 'gold'],
#  'Browns Creek': ['pct', 'BHPGM', 'portfolio', 'include', 'australian'],
#  'the Black\n  Sea': ['port', 'official', 'say', 'large', 'vessel'],
#  'the Sea of Marmara': ['port', 'official', 'say', 'large', 'vessel'],
#  'the South Korean Won': ['Taiwan', 'dollar', 'lie', 'soley', 'country'],
#  'the North\n  Sea': ['renewal', 'exploration', 'high', 'cost', 'area'],
#  'the Zurich Bourse': ['foreign', 'SOGENAL', 'french', 'bank', 'Austria'],
#  'South-East Asia': ['Indonesia', 'large', 'country', 'population', 'million'],
#  'the East coast': ['cost', 'revenue', 'depress', 'recent', 'price'],
#  'Pearl River\n  Counties': ['Endevco', 'Inc', 'say', 'agree', 'acquire'],
#  'Gordon Lake': ['gold', 'pct', 'cyanidation', 'Giant', 'Bay'],
#  'the European\n  weekend': ['traditional',
#   'Sunday',
#   'lull',
#   'trading',
#   'contribute'],
#  'Waste': ['interest', 'chemlawn', 'say', 'board', 'determine'],
#  'Mossel Bay': ['Soekor', 'say', 'continue', 'test', 'strike'],
#  'South Louisiana': ['permian', 'spokesman', 'say', 'sweet', 'post'],
#  'The Mississippi River': ['barge', 'spokesman', 'say', 'ice', 'open'],
#  'the Aguarico river': ['say', 'metre', 'section', 'pipeline', 'attach'],
#  'Ecaudor': ['quake', 'strike', 'northern', 'southern', 'Colombia'],
#  'the Ras Tanurah': ['mln', 'say', 'export', 'terminal', 'Gulf'],
#  'Nigerian Brass River': ['price', 'dlrs', 'oil', 'trader', 'say'],
#  'Beaufort Sea': ['Petroleum', 'stumble', 'block', 'Encor', 'mln'],
#  'South Bay': ['asset', 'mln', 'dlrs', 'FHLBB', 'say'],
#  'the St Lawrence river': ['second', 'big', 'loss', 'life', 'peacetime'],
#  'Mackay': ['balance', 'ship', 'end', 'March', 'Harper'],
#  'Port Moresby': ['say', 'hope', 'Papua', 'New', 'Guinea'],
#  'Misima Island': ['tonne', 'gram', 'Placer', 'estimate', 'epithermal'],
#  'the South China Sea': ['report', 'offshore', 'oil', 'find', 'Pearl'],
#  'South Bay S': ['mln', 'Friday', 'Federal', 'Home', 'Loan'],
#  'Wallenbergs': ['ST', 'oust', 'large', 'shareholder', 'SKF'],
#  'the Sea of\n  Marmara': ['Istanbul',
#   'remain',
#   'virtual',
#   'standstill',
#   'today'],
#  'Lake Michigan': ['wind', 'guste', 'mph', 'cause', 'foot'],
#  'south central Montana': ['western', 'snow', 'reach', 'Wyoming', 'Nebraska'],
#  'Terra Nova': ['Canada', 'Petro', 'company', 'say', 'field'],
#  'Hudson Bay Mining': ['HUDSON', 'BAY', 'MINING', 'CUTS', 'CANADA'],
#  'the Oak Hill': ['company', 'say', 'field', 'sell', 'half'],
#  'Soo Line': ['loss', 'mln', 'dlrs', 'say', 'net'],
#  'the Europe South': ['chairman', 'East', 'african', 'Conference', 'line'],
#  'South-East': ['chairman', 'Europe', 'african', 'Conference', 'line'],
#  'pacific\n  ': ['oil', 'cost', 'mln', 'dlrs', 'repair'],
#  'Southern Michigan': ['bbl', 'Sweet', 'raise', 'ct', 'dlrs'],
#  'the Arctic National Wildlife\n  Refuge': ['suggest',
#   'Alaska',
#   'open',
#   'lease',
#   'oil'],
#  'the South China': ['News', 'Corp', 'say', 'Morning', 'Post'],
#  'Continental Europe': ['mln', 'vs', 'region', 'Britain', 'contribute'],
#  'the\n  London': ['year', 'repayment', 'debt', 'stretch', 'grace'],
#  'the South\n  ': ['mln', 'dlrs', 'total', 'exclude', 'extraordinary'],
#  'the\n  river': ['port', 'Philadelphia', 'closed', 'cypriot', 'oil'],
#  'Hope Creek': ['say', 'oil', 'spill', 'ship', 'lodge'],
#  'the east coast': ['Ansbacher', 'say', 'P', 'exciting', 'growth'],
#  'Andes': ['maoist', 'guerrilla', 'dynamite', 'derail', 'locomotive'],
#  'Boone Pickens': ['pure', 'market', 'speculation', 'group', 'interested'],
#  'the Henrique Leal': ['port', 'source', 'say', 'brazilian', 'ship'],
#  '3rd qtr': ['loss', 'dlrs', 'vs', 'note', 'include'],
#  'the Great Plains': ['signup', 'area', 'expect', 'attract', 'great'],
#  'La\n  Pampa': ['mm', 'rainfall', 'total', 'Buenos', 'Aires'],
#  'Corrientes': ['mm', 'rainfall', 'total', 'San', 'Luis'],
#  'Paradise Valley': ['buy', 'Cotton', 'president', 'Finalco', 'Group'],
#  'the Channel Island': ['Ward', 'attorney', 'lawyer', 'Thomas', 'member'],
#  'Mid East': ['sale', 'tax', 'hurt', 'canadian', 'profit'],
#  'North America 34.7': ['mln', 'vs', 'Europe', 'Australasia'],
#  'Club Med\n  ': ['Touristique', 'carry', 'construction', 'work', 'financial'],
#  "the North Sea's": ['price', 'dlrs', 'range', 'say', 'OPEC'],
#  'NORTH AMERICA': ['CORRECTED', 'insituform'],
#  'RICE MARKET': ['ask', 'share', 'JAPAN'],
#  'Northern Alaska': ['National',
#   'Wildlife',
#   'Federation',
#   'reject',
#   'Interior'],
#  'the Welland\n  Canal': ['St', 'Lawrence', 'Seaway', 'link', 'Lakes'],
#  'Lakes Erie': ['St', 'Lawrence', 'Seaway', 'Welland', 'Canal'],
#  'Seaway': ['entire', 'free', 'ice', 'mild', 'winter'],
#  'the Western District': ['Alleghney', 'say', 'suit', 'file', 'Court'],
#  'Weinberger\n  ': ['Defense', 'Department', 'say', 'today', 'Baldrige'],
#  'Silicon Valley': [],
#  'The barley area': ['ha', 'unchanged', 'oilseed', 'rape', 'increase'],
#  'the Cook Strait': ['loading', 'unload', 'involve', 'harbour', 'board'],
#  'AMAX Sleeper\n  Mine': ['Incx', 'say', 'identify', 'additional', 'gold'],
#  'Great America': ['Penn', 'Central', 'Bally', 'buy', 'theme'],
#  'Pacific Ocean': ['pipeline', 'Colombia', 'say', 'month', 'mln'],
#  'the Pacific\n  Ocean': ['tremor', 'rupture', 'country', 'main', 'pipeline'],
#  'SETS PAYOUT\n  ': [],
#  'Fernando Valley': ['say', 'Cable', 'operate', 'subscriber', 'cable'],
#  "Beaver Creek's": ['dlrs', 'citizen', 'pay', 'premium', 'FDIC'],
#  'the Bay of Baes': ['separate', 'statement', 'issue', 'Tanjug', 'Ina'],
#  'the Bay of Gabes': ['work', 'second', 'drill', 'meter', 'start'],
#  'Middle\n  East': ['fledgling', 'private', 'sector', 'hard', 'hit'],
#  'Central Queensland': ['pct', 'coal', 'mine', 'operation', 'Utah'],
#  'Mid-East Gulf': ['billion', 'total', 'trade', 'state', 'fall'],
#  'Calny': ['Inc', 'PepsiCo', 'say', 'receive', 'offer'],
#  'Avia': ['stock', 'stockholder', 'defendant', 'Reebok', 'acquisition'],
#  'Europe\n  ': ['Funaro', 'say', 'recent', 'trip', 'Japan'],
#  'BOSS': [],
#  'Star Lake': ['say', 'sharp', 'rise', 'share', 'price'],
#  'Hudson Valley': ['provide', 'guard', 'patrol', 'service'],
#  'Mississippi': ['measure', 'Missouri', 'Republican', 'Senators', 'John'],
#  'New York Harbor': ['rally', 'lead', 'spot', 'month', 'heating'],
#  'Central District': ['federal', 'company', 'say', 'file', 'Federal'],
#  'the South West Advocate': ['Community', 'Newspapers', 'Inc', 'buy', 'Bend'],
#  'the South Bend Advocate': ['Community', 'Newspapers', 'Inc', 'buy', 'West'],
#  'Mississippi River': ['week', 'St', 'Louis', 'pct', 'offer'],
#  'Norhteast': ['say', 'year', 'end', 'receivables', 'dlrs'],
#  'Taft Broadcast': ['say',
#   'prepare',
#   'negotiate',
#   'transaction',
#   'shareholder'],
#  'Southern France': ['Petroleum',
#   'Intelligence',
#   'Weekly',
#   'influential',
#   'trade'],
#  'Southern Europe': ['oil', 'say', 'company', 'operation', 'Exxon'],
#  'the Southern Basin': ['point', 'relief', 'apply', 'development', 'new'],
#  'the North China\n  ': ['normal', 'February', 'temperature'],
#  'Transvaal': ['agency', 'say', 'dry', 'summary', 'Weather'],
#  'Al-Wattari': ['note', 'total', 'OPEC', 'output', 'organization'],
#  "Allegheny Beverage's": ['Service', 'America', 'revenue', 'dlrs', 'say'],
#  'Lynn Lake': ['own', 'remain', 'interest', 'project', 'locate'],
#  'the Hudson Valley': ['year', 'end', 'asset', 'mln', 'dlrs'],
#  'U.K. Base': ['market', 'rate', 'money', 'dealer', 'speculate'],
#  'south': ['say', 'weather', 'wetter'],
#  'the Midwest\n  ': ['price', 'soviet', 'buying', 'barge', 'freight'],
#  'LFIO': ['earning', 'reflect', 'charge', 'ct', 'share'],
#  "the Gulf of Mexico's": ['gas', 'big', 'offshore', 'water', 'reserve'],
#  'the Polar Sea': ['passage', 'government', 'announce', 'plan', 'build'],
#  'Marble Hill': ['PSI', 'report', 'qualified', 'auditor', 'Arthur'],
#  'Hemdale': ['March', 'Chatsworth', 'computer', 'disk', 'drive'],
#  'mlns tonnes': ['Czarnikow', 'projection', 'white', 'value', 'differ'],
#  'Czarnikow': ['tonne', 'mln', 'socialist', 'allow', 'current'],
#  'Peerless Lake': ['oil', 'barrel', 'day', 'zone', 'say'],
#  'Marinduque Mining and Industrial\n  Corp': ['Manila',
#   'banking',
#   'source',
#   'say',
#   'situation'],
#  'Key West Grill': ['Pillsbury', 'report', 'low', 'profit', 'Distron'],
#  'Oak Brook Hills\n  Hotel and Conference Center': ['company',
#   'say',
#   'early',
#   'April',
#   'suburban'],
#  'M0': ['Thomas', 'note', 'rise', 'keep', 'check'],
#  'the southern basin': ['restrict',
#   'new',
#   'offshore',
#   'development',
#   'outside'],
#  'central america': ['Martinez', 'Cuenca', 'tell', 'reporter', 'lose'],
#  'south-Atlantic': ['state'],
#  'Josten': ['total', 'proprietary', 'school', 'sale', 'mln'],
#  'the Arabian Sea': ['Kitty', 'Hawk', 'group', 'force', 'warplane'],
#  'the U.S. Mideast Task Force': ['Kitty', 'Hawk', 'group', 'Arabian', 'Sea'],
#  "Western Australia's": ['belt', 'concern', 'grow', 'average', 'rainfall'],
#  "Asia-Pacific region's": ['say', 'weather', 'El', 'Nino', 'Peru'],
#  'East Asia': [],
#  'Baltic': ['icy', 'condition', 'say', 'southern', 'soviet'],
#  'the Gulf of Bothnia': ['coastal', 'stretch', 'divide', 'Finland', 'Sweden'],
#  'East bloc': ['question', 'Zdzislaw', 'Kuroski', 'deputy', 'director'],
#  'Pine\n  Bluff': ['Inc', 'division', 'Eclipse', 'Illinois', 'Tool']}

# %% [markdown]
# ## Extra Credit
#
# There are several extra credit options for this assignment.
# * The first would be to determine which persons, organizations, and locations most frequently occur in the same sentences.
# * Another task would be to attempt to resolve different forms of the same name for each person and location. For example, George Bush and Bush inside the same document.

# %%
loc_per_org = {}

for location in top_locations:
    loc_per_org[location] = {}
    loc_per_org[location]['per'] = {}
    loc_per_org[location]['per']['org'] = 0
    sents = []
    for lst in combined_locations[location]:
        for tup in lst:
            sents.append(tup[1])
    for sent in sents:
        pers = set()
        orgs = set()
        analyzed = nlp(sent)
        for entity in analyzed.ents:
            if entity.text.strip() != "":
                if entity.label_ == 'PERSON':
                    pers.add(entity.text)
                if entity.label_ == 'ORG':
                    orgs.add(entity.text)
        for per in pers:
            if per not in loc_per_org[location]:
                loc_per_org[location][per] = {}
                loc_per_org[location][per]['org'] = 0
                for org in orgs:
                    loc_per_org[location][per][org] = 1
            else:
                for org in orgs:
                    if org not in loc_per_org[location][per]:
                        loc_per_org[location][per][org] = 1
                    else:
                        loc_per_org[location][per][org] += 1
nested_list = []
for loc in loc_per_org.items():
    for per in loc[1].items():
        for org in per[1].items():
            nested_list.append([loc[0], per[0], org[0], org[1]])
sorted_list = [item for item in sorted(nested_list, reverse=True, key=lambda x: x[3])]
sorted_list[:13]
# Out:
# [['Europe', 'Stora', 'Papyrus', 2],
#  ['Europe', 'Stora', 'Reed International Plc\n  &lt;REED L', 2],
#  ['Gulf', 'Mir-Hossein', 'U.S. Navy', 2],
#  ['Gulf', 'Avaj', 'Lloyds', 2],
#  ['the\n  Gulf', 'Alexander Ivanov', 'Foreign Ministry', 2],
#  ['the\n  Gulf', 'Al-Rai al-Aam', 'Foreign Ministry', 2],
#  ['Persian Gulf', 'Reagan', 'Kuwaiti', 2],
#  ['Arabian Sea', 'Kitty Hawk', 'Pentagon', 2],
#  ['the Pacific coast', 'Balao', 'Lago Agrio', 2],
#  ['Mideast Gulf', 'Reagan', 'House', 2],
#  ['Mideast Gulf', 'Reagan', 'Congress', 2],
#  ['the\n  Mark', 'Lira', 'Bank', 2],
#  ['Admiralty Island', 'Hecla', 'pct', 2]]
